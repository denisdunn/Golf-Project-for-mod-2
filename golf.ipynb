# %%
import pandas as pd
import numpy as np
import math
import scipy.stats as stats

import statsmodels.api as sm
from statsmodels.formula.api import ols
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('seaborn')

# %%
df=pd.read_csv('PGA Tour 2010-2018.csv')

# %%
golf=pd.read_csv('PGA_Data_Historical.csv')

# %%
golf.columns
# Out:
# Index(['Player Name', 'Season', 'Statistic', 'Variable', 'Value'], dtype='object')

# %%
set(golf.Variable)
# Out:
# {'Distance Analysis 180-190 yards - 7 Iron - (ROUNDS)',
#  "Total 1 Putts - 10-15' - (TOTAL)",
#  'Consecutive Par 5 Birdies - (EVENTS)',
#  'Distance Analysis 200-210 yards - 3 Iron - (ROUNDS)',
#  "GIR Putting Avg - > 35' - (PUTTS MADE)",
#  'Longest Putts - (HOLE)',
#  'Distance Analysis 240-260 yards - 2 Iron - (TOTAL ATTEMPTS DIST RANGE)',
#  'Carry Distance - (LONGEST CARRY DISTANCE)',
#  'Driving Pct. 300+ (All Drives) - (RELATIVE TO PAR)',
#  'Proximity to Hole from Other Locations - (# OF SHOTS)',
#  'Approaches from > 275 yards (Rgh) - (RELATIVE TO PAR)',
#  'Distance Analysis 190-200 yards - 6 Iron - (TOTAL ATTEMPTS DIST RANGE)',
#  'Approach 75-100 yards (RTP Score) - (ROUNDS)',
#  'Distance Analysis 240-260 yards - 3 Iron - (%)',
#  'Tenth Tee Late Lowest Round - (LOW RND)',
#  'Average Putting Distance - GIR 3+ Putts - (ROUNDS)',
#  'Distance Analysis 200-220 yards - 3 Iron - (ROUNDS)',
#  'Distance Analysis 190-200 yards - 3 Iron - (TOTAL ATTEMPTS WITH CLUB)',
#  'Percentage of Available Purse Won - (TOTAL PURSE AVAILABLE)',
#  'Birdie or Better Percentage - 150-175 yards - (TOTAL HOLES)',
#  'Left Tendency - (EVENTS)',
#  'Right Rough Proximity - (AVG)',
#  'Distance Analysis 240-260 yards - 5 Iron - (%)',
#  '11-25 Final Round Performance - (# OF TIMES IMPROVED)',
#  'Distance Analysis 220-240 yards - Wedges - (%)',
#  'Distance Analysis 180-190 yards - 4 Iron - (TOTAL ATTEMPTS DIST RANGE)',
#  'Fairway Bunker Tendency - (ROUNDS)',
#  'Approaches from 175-200 yards - (# OF ATTEMPTS)',
#  'Approach 225-250 yards (RTP) - (ROUNDS)',
#  'Distance Analysis 160-170 yards - Fairway Wood - (TOTAL ATTEMPTS DIST RANGE)',
#  'Average Distance of Putts made - (TOTAL DIST. (INCHES))',
#  'Birdie or Better Percentage - Fairway - (%)',
#  "Putting from 5-15' - (ATTEMPTS)",
#  'Proximity to Hole from < 10 yards - (ROUNDS)',
#  'Distance Analysis 180-190 yards - 3 Iron - (%)',
#  'First Tee Late Par 5 Scoring Average - (TOTAL HOLES)',
#  'Distance Analysis 200-220 yards - 8 Iron - (TOTAL ATTEMPTS DIST RANGE)',
#  'Driving Pct. <= 240 (Measured) - (TOTAL DRIVES FOR <= 240)',
#  'Percentage of Available Purse Won - (EVENTS)',
#  'Scrambling from 20-30 yards - (ATTEMPTS)',
#  'Bonus Putting - (VALUE)',
#  'Distance Analysis 240-260 yards - 6 Iron - (TOTAL ATTEMPTS WITH CLUB)',
#  'Distance Analysis 160-170 yards - 3 Iron - (%)',
#  'FedExCup Season Points - (RESET POINTS)',
#  'Distance Analysis 200-220 yards - 3 Iron - (TOTAL ATTEMPTS DIST RANGE)',
#  'Distance Analysis 210-220 yards - 8 Iron - (TOTAL ATTEMPTS WITH CLUB)',
#  'Distance Analysis 210-220 yards - 7 Iron - (%)',
#  'Bounce Back - (%)',
#  'Scrambling from Other Locations - (%)',
#  'Total Putting - (TOTAL)',
#  'All-Around Ranking - (TOTAL)',
#  'Official World Golf Ranking - (POINTS LOST)',
#  "Putting from 4-8' - (ATTEMPTS)",
#  'Driving Pct. 260-280 (Measured) - (ROUNDS)',
#  "GIR Putting - 20-25' - (ATTEMPTS)",
#  '2-Putts per Round - (AVG)',
#  'Proximity to Hole from 20-30 yards - (# OF SHOTS)',
#  'Distance Analysis 240-260 yards - Wedges - (ROUNDS)',
#  'PGA Championship Points - (EVENTS)',
#  'Distance Analysis 200-210 yards - 5 Iron - (TOTAL ATTEMPTS DIST RANGE)',
#  'Scrambling Rough (RTP Score) - (AVG RTP)',
#  'Par 3 Performance - (TOTAL PAR)',
#  '3-Putt Avoidance - (TOTAL HOLES (OVERALL))',
#  'Distance to Apex - (AVG.)',
#  'SG: Off-the-Tee - (TOTAL SG:OTT)',
#  'Distance Analysis < 80 yards - Driver - (%)',
#  'Driving Pct. <= 240 (Measured) - (RELATIVE TO PAR)',
#  'Approaches from 100-125 yards - (# OF ATTEMPTS)',
#  'Distance Analysis 190-200 yards - 9 Iron - (ROUNDS)',
#  'Distance Analysis 160-170 yards - Wedges - (TOTAL ATTEMPTS DIST RANGE)',
#  "GIR Putting Avg - 30-35' - (ROUNDS)",
#  'Percentage of Available Purse Won - (OFFICIAL MONEY WON)',
#  'Driving Pct. 240-260 (All Drives) - (TOTAL DRIVES FOR 240-260)',
#  'Ball Speed - (ROUNDS)',
#  'Last 15 Events - Putting - (EVENTS)',
#  "Putting from - 20-25' - (ATTEMPTS)",
#  'SG: Approach-the-Green - (AVERAGE)',
#  'Par Breakers - (%)',
#  'Birdie or Better Percentage - 200+ yards - (TOTAL HOLES)',
#  'Distance Analysis 260-280 yards - 3 Iron - (%)',
#  'Driving Pct. 300-320 (All Drives) - (TOTAL DRIVES - OVERALL)',
#  "% of Potential Pts won - FedExCup Regular Season - (# OF TOP 10'S)",
#  'Eagles (Holes per) - (FREQUENCY)',
#  'Tenth Tee Late Scoring Average - (TOTAL 10TH TEE LATE RNDS.)',
#  'Lowest Round - (ROUND)',
#  'Longest Putts - (DISTANCE)',
#  'Distance Analysis 190-200 yards - 7 Iron - (%)',
#  'Approaches < 100 yards-Rgh (RTP) - (ROUNDS)',
#  'Average Putting Distance - All 3 putts - (ROUNDS)',
#  'Approaches from 75-100 yards (Rgh) - (AVG)',
#  'Distance Analysis 180-190 yards - Fairway Wood - (TOTAL ATTEMPTS WITH CLUB)',
#  'Club Head Speed - (AVG.)',
#  'Birdie or Better Percentage - Right Rough - (TOTAL BIRDIES)',
#  'Distance Analysis 150-160 yards - 5 Iron - (ROUNDS)',
#  "Total 3 Putts - 15-20' - (TOTAL 3 PUTTS)",
#  'Distance Analysis 180-190 yards - 2 Iron - (%)',
#  'Spin Rate - (HIGHEST SPIN RATE)',
#  'Distance Analysis 240-260 yards - Driver - (TOTAL ATTEMPTS DIST RANGE)',
#  'Par 3 Birdie or Better Leaders - (PAR 3 HOLES)',
#  'SG: Approach-the-Green - (MEASURED ROUNDS)',
#  'Scrambling from < 10 yards - (ATTEMPTS)',
#  'Approach 75-100 yards (RTP Score) - (AVG RTP)',
#  'Bogey Avoidance - (HOLES PLAYED)',
#  'Last 5 Events - Short Game - (RATING)',
#  'Distance Analysis 130-140 yards - 6 Iron - (TOTAL ATTEMPTS DIST RANGE)',
#  'Distance Analysis 240-260 yards - 3 Iron - (TOTAL ATTEMPTS DIST RANGE)',
#  "Total 3 Putts - 20-25' - (ROUNDS)",
#  'GIR Percentage - 100+ yards - (%)',
#  'Average Putting Distance - All 1 putts - (TOTAL PUTTS)',
#  "GIR Putting - > 25' - (ATTEMPTS)",
#  'Right Rough Proximity - (ATTEMPTS)',
#  'Scoring Average (Actual) - (TOTAL STROKES)',
#  'Official World Golf Ranking - (TOTAL POINTS)',
#  'GIR Percentage from Other than Fairway - (GREENS HIT)',
#  'Current Streak without a 3-Putt - (EVENTS)',
#  'Distance Analysis 260-280 yards - 3 Iron - (TOTAL ATTEMPTS DIST RANGE)',
#  "Percentage of Yardage covered by Tee Shots - Par 5's - (ROUNDS)",
#  'Distance Analysis 130-140 yards - 7 Iron - (ROUNDS)',
#  'Proximity to Hole from Fringe - (# OF SHOTS)',
#  'Back 9 Par 5 Scoring Average - (AVG)',
#  "3-Putt Avoidance - 5-10' - (ATTEMPTS)",
#  'Distance Analysis 200-220 yards - 7 Iron - (%)',
#  'Distance Analysis 150-160 yards - 4 Iron - (TOTAL ATTEMPTS DIST RANGE)',
#  'Reverse Bounce Back - (% UNDER THEN OVER PAR)',
#  'Sand Save Percentage - (ROUNDS)',
#  'Distance Analysis 170-180 yards - Wedges - (TOTAL ATTEMPTS DIST RANGE)',
#  "GIR Putting - 10-15' - (ROUNDS)",
#  'Distance Analysis 240-260 yards - 7 Iron - (TOTAL ATTEMPTS WITH CLUB)',
#  'Scrambling from Other Locations - (ATTEMPTS)',
#  'Distance Analysis 200-220 yards - 8 Iron - (TOTAL ATTEMPTS WITH CLUB)',
#  'Scrambling - (%)',
#  'Bogey Avoidance - (BOGEYS)',
#  'Front 9 Par 3 Scoring Average - (TOTAL HOLES)',
#  "Total 1 Putts - 5-10' - (ROUNDS)",
#  'Par 5 Eagle Leaders - (TOTAL HOLE OUTS)',
#  "GIR Putting - 20-25' - (%)",
#  'Driving Pct. 280-300 (Measured) - (RELATIVE TO PAR)',
#  'Scrambling from < 10 yards - (%)',
#  "Putting from 4' - (PUTTS MADE)",
#  'Par 4 Eagle Leaders - (ROUNDS)',
#  'Distance Analysis 100-110 yards - 5 Iron - (%)',
#  'Distance Analysis 120-130 yards - 6 Iron - (TOTAL ATTEMPTS DIST RANGE)',
#  'Distance Analysis 260-280 yards - 3 Iron - (TOTAL ATTEMPTS WITH CLUB)',
#  'Distance Analysis 220-240 yards - Driver - (%)',
#  'Average Putting Distance - GIR 1 Putts - (AVG)',
#  'Sand Saves from 20-30 yards - (# OF SAVES)',
#  'Distance Analysis 200-220 yards - Driver - (ROUNDS)',
#  'Best YTD Streak w/o a 3-Putt - (BEST STREAK)',
#  'Proximity to Hole from 30+ yards - (ROUNDS)',
#  'Early Scoring Average - (TOTAL EARLY ROUNDS)',
#  "Rounds in the 60's - (TOTAL RNDS)",
#  'Distance Analysis 210-220 yards - 6 Iron - (%)',
#  'Par 3 Birdie or Better Leaders - (ROUNDS)',
#  'Scrambling from 10-20 yards - (ROUNDS)',
#  'Approaches from inside 100 yards (Rgh) - (RELATIVE TO PAR)',
#  'Driving Pct. 240-260 (All Drives) - (ROUNDS)',
#  "GIR Putting - 15-20' - (ATTEMPTS)",
#  'Average Putting Distance - GIR 1 Putts - (TOTAL PUTTS)',
#  'Distance Analysis 100-110 yards - Driver - (TOTAL ATTEMPTS WITH CLUB)',
#  'Smash Factor - (ROUNDS)',
#  'Good Drive Percentage - (# HIT)',
#  'Greens or Fringe in Regulation - (RTP SCORE)',
#  'Proximity to Hole from Rough - (AVG DTP)',
#  'Distance Analysis 210-220 yards - 6 Iron - (TOTAL ATTEMPTS WITH CLUB)',
#  'Distance Analysis 100-110 yards - Driver - (ROUNDS)',
#  'Hit Fairway Percentage - (RELATIVE TO PAR)',
#  'Distance Analysis 240-260 yards - 2 Iron - (TOTAL ATTEMPTS WITH CLUB)',
#  'Distance Analysis 200-210 yards - Fairway Wood - (ROUNDS)',
#  'First Tee Early Par 4 Scoring Average - (ROUNDS)',
#  'Distance Analysis 220-240 yards - 4 Iron - (TOTAL ATTEMPTS WITH CLUB)',
#  'Distance Analysis 260-280 yards - 5 Iron - (%)',
#  'Consecutive Sand Saves - (YEAR/TOURN#)',
#  'Distance Analysis 150-160 yards - 4 Iron - (ROUNDS)',
#  'Sand Saves from < 10 yards - (%)',
#  'Approaches from inside 100 yards - (TOTAL DISTANCE (FEET))',
#  'Percentage of Yardage covered by Tee Shots - (TOTAL DISTANCE)',
#  'Early Par 4 Scoring Average - (TOTAL HOLES)',
#  'Driving Pct. 320+ (Measured) - (%)',
#  'Par 5 Birdie or Better Leaders - (PAR 5 BIRDIES OR BETTER)',
#  'Tenth Tee Late Par 4 Scoring Average - (ROUNDS)',
#  'Distance from Edge of Fairway - (EVENTS)',
#  'Par 5 Going for the Green - (%)',
#  'Distance Analysis 100-110 yards - 5 Iron - (TOTAL ATTEMPTS DIST RANGE)',
#  'Distance Analysis 200-210 yards - 4 Iron - (%)',
#  'Rough Proximity - (AVG)',
#  "Percentage of Yardage covered by Tee Shots - Par 4's - (ROUNDS)",
#  'Money per Event Leaders - (TOTAL MONEY)',
#  'Birdie or Better Percentage - < 125 yards - (ROUNDS)',
#  'Driving Distance - (AVG.)',
#  'Distance Analysis 210-220 yards - 5 Iron - (TOTAL ATTEMPTS DIST RANGE)',
#  'Distance Analysis 260-280 yards - 5 Iron - (TOTAL ATTEMPTS WITH CLUB)',
#  'Distance Analysis 190-200 yards - 7 Iron - (ROUNDS)',
#  'Early Par 5 Scoring Average - (TOTAL HOLES)',
#  'Distance Analysis 240-260 yards - 5 Iron - (ROUNDS)',
#  'Distance Analysis 180-190 yards - 3 Iron - (ROUNDS)',
#  'Distance Analysis 200-220 yards - 2 Iron - (%)',
#  'Approaches 50-75 yards-Rgh (RTP) - (ROUNDS)',
#  'Par 4 Birdie or Better Leaders - (PAR 4 HOLES)',
#  "Putting from - 10-15' - (ATTEMPTS)",
#  'GIR Percentage - 75-100 yards - (%)',
#  'Approach 175-200 yards (RTP Score) - (ROUNDS)',
#  'SG: Around-the-Green - (TOTAL SG:ARG)',
#  'Distance Analysis 130-140 yards - 9 Iron - (%)',
#  'Distance Analysis 180-190 yards - 7 Iron - (TOTAL ATTEMPTS WITH CLUB)',
#  'Distance Analysis 130-140 yards - 6 Iron - (ROUNDS)',
#  'Consecutive GIR - (YEAR/TOURN#)',
#  'Approaches from 175-200 yards - (RELATIVE TO PAR)',
#  "3-Putt Avoidance - 20-25' - (ATTEMPTS)",
#  'Driving Pct. 260-280 (Measured) - (TOTAL DRVS - OVERALL)',
#  'Total Hole Outs - (HOLE OUTS)',
#  'Scrambling Fringe (RTP Score) - (TOTAL HOLES)',
#  '25+ Final Round Performance - (% TIMES IMPROVED)',
#  'Distance Analysis 160-170 yards - 5 Iron - (%)',
#  'Last 5 Events - Scoring - (EVENTS)',
#  'Distance Analysis 140-150 yards - 6 Iron - (%)',
#  'SG: Tee-to-Green - (SG:APR)',
#  'Power Rating - (EVENTS)',
#  'Average Putting Distance - All 2 putts - (AVG)',
#  'Proximity to Hole from Rough - (# OF SHOTS)',
#  'Scrambling from the Rough - (%)',
#  '3-Putts per Round - (TOTAL ROUNDS)',
#  'Distance Analysis 150-160 yards - Driver - (TOTAL ATTEMPTS WITH CLUB)',
#  "GIR Putting - Inside 5' - (%)",
#  'Approaches from inside 100 yards (Rgh) - (TOTAL DISTANCE (FEET))',
#  'Front 9 Par 4 Scoring Average - (TOTAL HOLES)',
#  'Distance Analysis 190-200 yards - 6 Iron - (TOTAL ATTEMPTS WITH CLUB)',
#  'Consecutive Fairways Hit - (CURRENT STREAK)',
#  'Back 9 Par 3 Scoring Average - (TOTAL HOLES)',
#  "FedExCup Standings - (# OF TOP 10'S)",
#  'Approaches from > 200 yards (Rgh) - (RELATIVE TO PAR)',
#  'Distance Analysis 190-200 yards - 8 Iron - (ROUNDS)',
#  'Birdie or Better Percentage - 125-150 yards - (%)',
#  "Putts Made Per Event Over 10' - (ROUNDS)",
#  'Tenth Tee Late Par 5 Scoring Average - (TOTAL HOLES)',
#  'SG: Tee-to-Green - (MEASURED ROUNDS)',
#  'Driving Pct. 320+ (All Drives) - (TOTAL DRIVES FOR 320+)',
#  'Distance Analysis 190-200 yards - Driver - (%)',
#  'Distance Analysis 120-130 yards - 8 Iron - (TOTAL ATTEMPTS WITH CLUB)',
#  "Putting from 15-25' - (PUTTS MADE)",
#  'Birdie to Bogey Ratio - (BIRDIE TO BOGEY RATIO)',
#  'Average Distance to Hole After Tee Shot - (ROUNDS)',
#  'Consecutive Holes Below Par - (NUMBER OF HOLES)',
#  'Distance Analysis 180-190 yards - 5 Iron - (ROUNDS)',
#  "Putting from 10' - (PUTTS MADE)",
#  'Eagles (Holes per) - (# OF EAGLES)',
#  'Driving Pct. <= 240 (All Drives) - (ROUNDS)',
#  'Accuracy Rating - (RATING)',
#  "Putting from 5-15' - (PUTTS MADE)",
#  'Rough Tendency - (POSSIBLE FWYS)',
#  'Distance Analysis 220-240 yards - 2 Iron - (TOTAL ATTEMPTS DIST RANGE)',
#  'Driving Accuracy Percentage - (FAIRWAYS HIT)',
#  'Percentage of Yardage covered by Tee Shots - (TOTAL SHOT DISTANCE)',
#  'Distance Analysis 170-180 yards - Wedges - (TOTAL ATTEMPTS WITH CLUB)',
#  'Distance Analysis 210-220 yards - 4 Iron - (ROUNDS)',
#  'Approaches from 75-100 yards - (TOTAL DISTANCE (FEET))',
#  'Distance Analysis 260-280 yards - 4 Iron - (%)',
#  'Missed Fairway Percent - Other - (TOTAL FWYS)',
#  'Distance Analysis 200-220 yards - Fairway Wood - (TOTAL ATTEMPTS DIST RANGE)',
#  'Distance Analysis 180-190 yards - 3 Iron - (TOTAL ATTEMPTS DIST RANGE)',
#  'Approaches from > 100 yards - (TOTAL DISTANCE (FEET))',
#  'Distance Analysis 200-210 yards - 2 Iron - (%)',
#  'Putting Average - (BIRDIE CONVERSION)',
#  '2-Putts per Round - (TOTAL 2 PUTTS)',
#  'Distance Analysis 160-170 yards - Wedges - (ROUNDS)',
#  'Last 5 Events - Short Game - (EVENTS)',
#  'Distance Analysis 220-240 yards - 8 Iron - (TOTAL ATTEMPTS WITH CLUB)',
#  'Launch Angle - (ROUNDS)',
#  'Proximity to Hole from Sand - (# OF SHOTS)',
#  'GIR Percentage from Other than Fairway - (%)',
#  'Putting Average - (ROUNDS)',
#  'GIR Percentage - 100-125 yards - (RELATIVE TO PAR)',
#  'GIR Percentage - 200+ yards - (GREENS HIT)',
#  'Missed Fairway Percent - Other - (ROUNDS)',
#  'Approaches from 125-150 yards (Rgh) - (TOTAL DISTANCE (FEET))',
#  'Par 5 Going for the Green - (ROUNDS)',
#  'Bogey Average - (AVERAGE BOGEYS PER ROUND)',
#  'Distance Analysis 220-240 yards - Fairway Wood - (%)',
#  "Total 3 Putts - 5-10' - (TOTAL 3 PUTTS)",
#  'Distance Analysis 170-180 yards - 3 Iron - (TOTAL ATTEMPTS DIST RANGE)',
#  'Late Par 4 Scoring Average - (TOTAL HOLES)',
#  'Spin Rate - (ROUNDS)',
#  'Carry Distance - (ROUNDS)',
#  'Distance Analysis 110-120 yards - 7 Iron - (ROUNDS)',
#  'Driving Pct. 320+ (Measured) - (TOTAL DRIVES FOR 320+)',
#  'Scoring Average (Actual) - (AVG)',
#  'Par 5 Birdie or Better Leaders - (ROUNDS)',
#  'Last 15 Events - Short Game - (RATING)',
#  'Proximity to Hole from 30+ yards - (AVG DTP)',
#  'Driving Pct. 280-300 (Measured) - (TOTAL DRIVES FOR 280-300)',
#  'Total Distance Efficiency - (TOTAL ATTEMPTS)',
#  'Proximity to Hole from Sand - (SCRAMBLING RANK)',
#  'Average Putting Distance - GIR 3+ Putts - (TOTAL PUTTS)',
#  'Proximity to Hole - (ROUNDS)',
#  'Approaches from > 275 yards - (# OF ATTEMPTS)',
#  'Distance Analysis 160-170 yards - 7 Iron - (%)',
#  'Approaches > 200 yards-Rgh (RTP) - (ROUNDS)',
#  'Ball Striking - (GIR RANK)',
#  'Distance Analysis 150-160 yards - 6 Iron - (TOTAL ATTEMPTS WITH CLUB)',
#  'Birdie or Better Percentage - Rough - (%)',
#  'Going for the Green - (ATTEMPTS)',
#  'GIR Percentage from Fairway - (# OF HOLES)',
#  'Average Approach Distance - Birdie or Better - (TOTAL DISTANCE (INCHES))',
#  'Distance Analysis 160-170 yards - 8 Iron - (TOTAL ATTEMPTS WITH CLUB)',
#  'SG: Putting - (AVERAGE)',
#  'Ball Speed - (TOTAL BALL SPEED)',
#  'Scrambling Average Distance to Hole - (AVG DTP)',
#  'Driving Pct. 240-260 (Measured) - (RELATIVE TO PAR)',
#  'Distance Analysis < 80 yards - 2 Iron - (TOTAL ATTEMPTS DIST RANGE)',
#  'Distance to Apex - (ROUNDS)',
#  'GIR Pct. - Fairway Bunker - (# HOLES)',
#  'Tenth Tee Early Lowest Round - (ROUNDS)',
#  "3-Putt Avoidance - 5-10' - (%)",
#  'Distance Analysis 200-220 yards - Fairway Wood - (TOTAL ATTEMPTS WITH CLUB)',
#  "Bonus Putting - (ATTEMPTS(<= 5'))",
#  'Going for the Green - Hit Green Pct. - (ROUNDS)',
#  'Approaches from 75-100 yards (Rgh) - (TOTAL DISTANCE (FEET))',
#  'Par 5 Eagle Leaders - (ROUNDS)',
#  'Approaches Right Rough (RTP Score) - (ROUNDS)',
#  'Going for the Green - Hit Green Pct. - (%)',
#  'Distance Analysis 150-160 yards - 6 Iron - (ROUNDS)',
#  'Distance Analysis 190-200 yards - 4 Iron - (ROUNDS)',
#  'Distance Analysis 130-140 yards - 7 Iron - (%)',
#  'Driving Pct. 320+ (All Drives) - (%)',
#  "Putting - Inside 10' - (ATTEMPTS)",
#  'Distance Analysis 170-180 yards - 8 Iron - (TOTAL ATTEMPTS WITH CLUB)',
#  'Distance Analysis 220-240 yards - 6 Iron - (%)',
#  'Distance Analysis 210-220 yards - Fairway Wood - (TOTAL ATTEMPTS DIST RANGE)',
#  'Last 15 Events - Scoring - (RATING)',
#  'Approaches from inside 100 yards - (ROUNDS)',
#  'Percentage of potential money won - (EVENTS)',
#  'Approaches from > 100 yards (Rgh) - (TOTAL DISTANCE (FEET))',
#  'Total Driving Efficiency - (ROUNDS)',
#  "GIR Putting Avg - > 35' - (ROUNDS)",
#  'Approaches from 175-200 yards (Rgh) - (# OF ATTEMPTS)',
#  'Greens in Regulation Percentage - (ROUNDS)',
#  "Putting from 3' - (PUTTS MADE)",
#  "Putting from - 15-20' - (% MADE)",
#  'Early Par 4 Scoring Average - (ROUNDS)',
#  'Distance Analysis 110-120 yards - 9 Iron - (ROUNDS)',
#  'Distance Analysis 200-210 yards - 2 Iron - (TOTAL ATTEMPTS DIST RANGE)',
#  'Distance Analysis 240-260 yards - 6 Iron - (%)',
#  'Consecutive GIR - (CURRENT STREAK)',
#  'Distance Analysis 200-210 yards - 6 Iron - (TOTAL ATTEMPTS WITH CLUB)',
#  'Approaches from 100-125 yards - (AVG)',
#  "Total 1 Putts - > 25' - (TOTAL)",
#  'Distance Analysis 260-280 yards - 8 Iron - (TOTAL ATTEMPTS DIST RANGE)',
#  'Approaches from 150-175 yards (Rgh) - (ROUNDS)',
#  'Scrambling from the Fringe - (%)',
#  'Approach 200-225 yards (RTP) - (ROUNDS)',
#  'SG: Off-the-Tee - (ROUNDS)',
#  'Distance Analysis 210-220 yards - 3 Iron - (%)',
#  '3-Putt Avoidance - (TOTAL 3 PUTTS)',
#  '% of Potential Pts won - FedExCup Playoffs - (%)',
#  'Apex Height - (ROUNDS)',
#  'Approaches 250-275 yards-Rgh (RTP) - (ROUNDS)',
#  "Putting from - > 20' - (PUTTS MADE)",
#  'Distance Analysis 220-240 yards - 6 Iron - (ROUNDS)',
#  "3-Putt Avoidance - Inside 5' - (%)",
#  'Distance Analysis < 80 yards - Fairway Wood - (%)',
#  'Distance Analysis < 80 yards - Driver - (TOTAL ATTEMPTS DIST RANGE)',
#  'Scrambling Average Distance to Hole - (ATTEMPTS)',
#  'Distance Analysis 240-260 yards - 7 Iron - (ROUNDS)',
#  'Birdie Average - (TOTAL ROUNDS)',
#  'GIR Percentage - 200+ yards - (TOTAL HOLES)',
#  'Average Putting Distance - All 2 putts - (DISTANCE (FEET))',
#  '1-Putts per Round - (ROUNDS)',
#  'Total Eagles - (TOTAL)',
#  'Distance Analysis 180-190 yards - Fairway Wood - (%)',
#  "3-Putt Avoidance - 5-10' - (TOTAL 3 PUTTS)",
#  'Approaches from > 275 yards (Rgh) - (AVG)',
#  'GIR Pct. - Fairway Bunker - (RELATIVE/PAR)',
#  'Early Par 5 Scoring Average - (TOTAL STROKES)',
#  'First Tee Early Scoring Average - (TOTAL STROKES)',
#  'Distance Analysis 140-150 yards - 9 Iron - (TOTAL ATTEMPTS DIST RANGE)',
#  'Best YTD Streak w/o a 3-Putt - (EVENTS)',
#  'Driving Pct. 300-320 (All Drives) - (TOTAL DRIVES FOR 300-320)',
#  "Total 3 Putts - 5-10' - (TOTAL 3 PUTTS 5'-10')",
#  'Distance Analysis 140-150 yards - 9 Iron - (TOTAL ATTEMPTS WITH CLUB)',
#  'Hang Time - (TOTAL ATTEMPTS)',
#  "Putting from - > 25' - (ROUNDS)",
#  'Bogey Avoidance - (ROUNDS)',
#  'Distance Analysis 150-160 yards - 8 Iron - (TOTAL ATTEMPTS WITH CLUB)',
#  'Average Approach Distance - Birdie or Better - (AVG (YARDS))',
#  'Driving Pct. 280-300 (All Drives) - (%)',
#  'Left Tendency - (ATTEMPTS)',
#  'Distance Analysis 220-240 yards - 5 Iron - (TOTAL ATTEMPTS DIST RANGE)',
#  'Distance Analysis 210-220 yards - Fairway Wood - (%)',
#  'Scrambling from the Sand - (ATTEMPTS)',
#  'Proximity to Hole from 20-30 yards - (SCRAMBLING RANK)',
#  'Distance Analysis 240-260 yards - Wedges - (TOTAL ATTEMPTS WITH CLUB)',
#  'Distance Analysis 140-150 yards - Fairway Wood - (%)',
#  'Distance Analysis 120-130 yards - 7 Iron - (TOTAL ATTEMPTS WITH CLUB)',
#  'Distance Analysis 170-180 yards - 9 Iron - (TOTAL ATTEMPTS WITH CLUB)',
#  'Distance Analysis 190-200 yards - 5 Iron - (ROUNDS)',
#  'Driving Pct. 300+ (Measured) - (TOTAL DRVS - OVERALL)',
#  'Distance Analysis 140-150 yards - Wedges - (TOTAL ATTEMPTS WITH CLUB)',
#  'Early Par 3 Scoring Average - (ROUNDS)',
#  'Putting Average - (GREENS HIT)',
#  'Distance Analysis 220-240 yards - 7 Iron - (ROUNDS)',
#  'Approach 250-275 yards (RTP) - (AVG RTP)',
#  'Distance Analysis 180-190 yards - Driver - (%)',
#  'Distance Analysis 190-200 yards - Fairway Wood - (TOTAL ATTEMPTS WITH CLUB)',
#  'Distance Analysis 240-260 yards - Wedges - (TOTAL ATTEMPTS DIST RANGE)',
#  'Approaches from > 100 yards (Rgh) - (# OF ATTEMPTS)',
#  'Approaches from > 275 yards (Rgh) - (ROUNDS)',
#  'Tenth Tee Late Par 5 Scoring Average - (AVG)',
#  "3-Putt Avoidance > 25' - (ATTEMPTS)",
#  'Distance Analysis 240-260 yards - 9 Iron - (TOTAL ATTEMPTS DIST RANGE)',
#  'Distance Analysis 110-120 yards - 9 Iron - (TOTAL ATTEMPTS DIST RANGE)',
#  'First Tee Early Par 5 Scoring Average - (TOTAL HOLES)',
#  'Distance Analysis 210-220 yards - 9 Iron - (TOTAL ATTEMPTS WITH CLUB)',
#  'Distance Analysis 180-190 yards - 9 Iron - (ROUNDS)',
#  'Proximity to Hole from 20-30 yards - (ROUNDS)',
#  'Approaches from 50-75 yards (Rgh) - (# OF ATTEMPTS)',
#  'Ball Striking - (TOTAL DRV RANK)',
#  'Distance Analysis 180-190 yards - 8 Iron - (%)',
#  'Distance Analysis 140-150 yards - Driver - (TOTAL ATTEMPTS WITH CLUB)',
#  'Distance Analysis 240-260 yards - 9 Iron - (ROUNDS)',
#  'Top 10 Finishes - (2ND)',
#  "Total 3 Putts - > 25' - (ROUNDS)",
#  'Total Birdies - (TOTAL)',
#  'GIR Percentage from Other than Fairway - (# OF HOLES)',
#  'Approaches from 50-75 yards - (TOTAL DISTANCE (FEET))',
#  'Front 9 Par 3 Scoring Average - (AVG)',
#  'Distance Analysis 160-170 yards - 6 Iron - (TOTAL ATTEMPTS DIST RANGE)',
#  "GIR Putting - 5-10' - (ATTEMPTS)",
#  'Going for the Green - Birdie or Better - (# OF BIRDIE OR BETTER)',
#  'Greens or Fringe in Regulation - (%)',
#  'Par 5 Performance - (ROUNDS)',
#  'Average Distance to Hole After Tee Shot - (TOTAL DIST AFTER TEE SHOT)',
#  'Distance Analysis 150-160 yards - Driver - (%)',
#  'Longest Drives - (TOURNAMENT)',
#  "GIR Putting - Inside 5' - (ROUNDS)",
#  'Victory Leaders - (EVENTS)',
#  'Distance Analysis 170-180 yards - 2 Iron - (%)',
#  'Right Rough Proximity - (RELATIVE TO PAR)',
#  'Distance Analysis 100-110 yards - Driver - (TOTAL ATTEMPTS DIST RANGE)',
#  'Approaches from 125-150 yards (Rgh) - (ROUNDS)',
#  'Distance Analysis 180-190 yards - 5 Iron - (TOTAL ATTEMPTS WITH CLUB)',
#  'Distance Analysis 160-170 yards - 8 Iron - (%)',
#  'Distance Analysis 200-210 yards - Driver - (TOTAL ATTEMPTS WITH CLUB)',
#  "GIR Putting Avg - 25-30' - (ATTEMPTS)",
#  'Driving Pct. 320+ (All Drives) - (ROUNDS)',
#  'Presidents Cup (International) - (POINTS GAINED)',
#  'Distance Analysis 170-180 yards - 3 Iron - (ROUNDS)',
#  'Birdie or Better Conversion Percentage - (GREENS HIT)',
#  'Proximity to Hole from Sand - (TOTAL DISTANCE (FEET))',
#  'Distance Analysis 260-280 yards - 6 Iron - (%)',
#  'Distance Analysis 150-160 yards - Fairway Wood - (TOTAL ATTEMPTS WITH CLUB)',
#  'Distance Analysis 210-220 yards - Fairway Wood - (TOTAL ATTEMPTS WITH CLUB)',
#  'Driving Distance - All Drives - (TOTAL DISTANCE)',
#  'Distance Analysis 140-150 yards - 8 Iron - (%)',
#  'Scoring Average - (TOTAL ROUNDS)',
#  'Distance Analysis 150-160 yards - 7 Iron - (%)',
#  'Early Par 4 Scoring Average - (AVG)',
#  'Approaches from 200-225 yards (Rgh) - (# OF ATTEMPTS)',
#  'Approaches from > 100 yards (Rgh) - (AVG)',
#  '3-Putt Avoidance - (ROUNDS)',
#  'Consecutive GIR - (ROUND)',
#  'Scrambling from 10-20 yards - (SUCCESSES)',
#  'Spin Rate - (LOWEST SPIN RATE)',
#  'Average Approach Distance - Par - (TOTAL DISTANCE (INCHES))',
#  'Back 9 Scoring Average - (AVG)',
#  'Distance Analysis 200-220 yards - Wedges - (TOTAL ATTEMPTS WITH CLUB)',
#  'Distance Analysis 160-170 yards - 8 Iron - (ROUNDS)',
#  'Average Distance of Birdie putts made - (TOT BIRDIE PUTTS MADE)',
#  'GIR Percentage - 150-175 yards - (RELATIVE TO PAR)',
#  'Distance Analysis 240-260 yards - 4 Iron - (TOTAL ATTEMPTS DIST RANGE)',
#  'Distance Analysis 180-190 yards - 8 Iron - (TOTAL ATTEMPTS WITH CLUB)',
#  'Approaches > 100 yards-Rgh (RTP) - (AVG RTP)',
#  'Scrambling from the Sand - (%)',
#  'Distance Analysis 180-190 yards - 2 Iron - (TOTAL ATTEMPTS WITH CLUB)',
#  'Distance Analysis 180-190 yards - 2 Iron - (ROUNDS)',
#  'Distance Analysis 160-170 yards - Driver - (TOTAL ATTEMPTS DIST RANGE)',
#  'All-Around Ranking - (EVENTS)',
#  'FedExCup Standings - (# OF WINS)',
#  'Proximity to Hole from Other Locations - (ROUNDS)',
#  'Non-Member Off+WGC Earnings - (WGC MONEY ONLY)',
#  "Percentage of Yardage covered by Tee Shots - Par 5's - (AVG (%))",
#  'Distance Analysis 100-110 yards - Fairway Wood - (ROUNDS)',
#  'Driving Pct. 280-300 (Measured) - (%)',
#  "GIR Putting Avg - > 35' - (% MADE)",
#  'Apex Height - (HIGHEST APEX POINT)',
#  'Scrambling from Other Locations - (ROUNDS)',
#  'FedExCup Standings - (RESET POINTS)',
#  'Distance Analysis 200-220 yards - Driver - (TOTAL ATTEMPTS DIST RANGE)',
#  'Approaches from 50-75 yards - (AVG)',
#  'Distance Analysis 110-120 yards - Wedges - (TOTAL ATTEMPTS DIST RANGE)',
#  'Average Putting Distance - GIR 1 Putts - (ROUNDS)',
#  'Distance Analysis 160-170 yards - 4 Iron - (TOTAL ATTEMPTS DIST RANGE)',
#  'Percentage of Yardage covered by Tee Shots - (ROUNDS)',
#  'Tenth Tee Early Scoring Average - (TOTAL STROKES)',
#  'First Tee Early Par 4 Scoring Average - (TOTAL STROKES)',
#  'Distance Analysis 190-200 yards - 8 Iron - (TOTAL ATTEMPTS WITH CLUB)',
#  '% of Potential Pts won - FedExCup Regular Season - (POINTS WON)',
#  'Average Distance to Hole After Tee Shot - (TOTAL TEE SHOTS)',
#  'Consecutive Birdies/Eagles streak - (EVENTS)',
#  'Distance Analysis 210-220 yards - Wedges - (TOTAL ATTEMPTS DIST RANGE)',
#  'Distance Analysis 200-220 yards - 4 Iron - (ROUNDS)',
#  'Distance Analysis 140-150 yards - 9 Iron - (%)',
#  'Distance Analysis 180-190 yards - 8 Iron - (ROUNDS)',
#  'Distance Analysis 120-130 yards - Driver - (ROUNDS)',
#  'Consecutive Sand Saves - (EVENTS)',
#  'Distance Analysis 220-240 yards - 8 Iron - (%)',
#  'Ball Striking - (VALUE)',
#  'Birdie or Better Percentage - (%)',
#  'Consecutive Fairways Hit - (BEST STREAK)',
#  'Scrambling > 30 yds (RTP Score) - (AVG RTP)',
#  'Putting Average - (AVG)',
#  'Approaches from 225-250 yards (Rgh) - (ROUNDS)',
#  'Approaches from 125-150 yards - (AVG)',
#  'Distance Analysis 200-220 yards - 6 Iron - (TOTAL ATTEMPTS DIST RANGE)',
#  "Putting - Inside 10' - (PUTTS MADE)",
#  "GIR Putting Avg - > 35' - (ATTEMPTS)",
#  'Driving Pct. 280-300 (All Drives) - (TOTAL DRIVES FOR 280-300)',
#  'Spin Rate - (TOTAL SPIN SPEED)',
#  'Approaches from > 200 yards (Rgh) - (AVG)',
#  'Proximity to Hole from Other Locations - (AVG DTP)',
#  'Consecutive Holes Below Par - (EVENTS)',
#  'Distance Analysis 240-260 yards - Fairway Wood - (ROUNDS)',
#  "Putting from 3-5' - (ROUNDS)",
#  'Driving Pct. 300-320 (Measured) - (RELATIVE TO PAR)',
#  'Proximity to Hole (ARG) - (SCRAMBLING RANK)',
#  'Club Head Speed - (FASTEST SPEED)',
#  'Distance Analysis 170-180 yards - Fairway Wood - (%)',
#  'Average Putting Distance - All 3+ putts - (TOTAL PUTTS)',
#  'Average Putting Distance - GIR 2 Putts - (ROUNDS)',
#  'Total Driving - (TOTAL)',
#  'Distance Analysis < 80 yards - Wedges - (ROUNDS)',
#  "Putting from 15-25' - (ROUNDS)",
#  'Distance Analysis 220-240 yards - Driver - (TOTAL ATTEMPTS DIST RANGE)',
#  'Distance Analysis 210-220 yards - 5 Iron - (ROUNDS)',
#  'Last 15 Events - Scoring - (EVENTS)',
#  'Birdie or Better Conversion Percentage - (# BIRDIES)',
#  'Par 5 Eagle Leaders - (TOTAL)',
#  'Percentage of Yardage covered by Tee Shots - (AVG (%))',
#  'FedExCup Season Points for Non-Members - (POINTS)',
#  'SG: Approach-the-Green - (TOTAL SG:APP)',
#  'Distance Analysis 240-260 yards - Fairway Wood - (TOTAL ATTEMPTS WITH CLUB)',
#  'Distance Analysis 200-220 yards - 3 Iron - (%)',
#  'Early Par 3 Scoring Average - (TOTAL HOLES)',
#  'GIR Percentage - 150-175 yards - (ROUNDS)',
#  'Distance Analysis 130-140 yards - 7 Iron - (TOTAL ATTEMPTS DIST RANGE)',
#  'GIR Percentage - < 100 yards - (ROUNDS)',
#  'Approaches from 50-75 yards (Rgh) - (ROUNDS)',
#  'Driving Distance - All Drives - (# OF DRIVES)',
#  'Longest Drives - (ROUNDS)',
#  "Putting from - > 10' - (% MADE)",
#  'Distance Analysis 200-220 yards - 4 Iron - (TOTAL ATTEMPTS WITH CLUB)',
#  "Putts Made Per Event Over 20' - (ROUNDS)",
#  'Rough Proximity - (TOTAL DISTANCE (INCHES))',
#  'Total Hole Outs - (ROUNDS)',
#  'Approach 175-200 yards (RTP Score) - (AVG RTP)',
#  'Distance Analysis 210-220 yards - 2 Iron - (%)',
#  'One-Putt Percentage - Round 1 - (ROUNDS)',
#  'Distance Analysis 200-220 yards - 8 Iron - (ROUNDS)',
#  'Distance Analysis 200-210 yards - Fairway Wood - (TOTAL ATTEMPTS WITH CLUB)',
#  "Putting from 4' - (ROUNDS)",
#  'Distance Analysis 200-210 yards - 4 Iron - (TOTAL ATTEMPTS WITH CLUB)',
#  'Approaches 175-200 yards-Rgh (RTP) - (ROUNDS)',
#  'Approach > 275 yards (RTP) - (AVG RTP)',
#  'GIR Percentage - < 125 yards - (TOTAL HOLES)',
#  'Par 4 Performance - (STATUS)',
#  'Greens in Regulation Percentage - (%)',
#  'Distance Analysis 190-200 yards - 2 Iron - (%)',
#  'FedExCup Standings - (POINTS)',
#  'Going for the Green - Birdie or Better - (ATTEMPTS)',
#  'Distance Analysis 100-110 yards - 5 Iron - (ROUNDS)',
#  'Distance Analysis 210-220 yards - Wedges - (ROUNDS)',
#  'Front 9 Par 5 Scoring Average - (AVG)',
#  'Distance Analysis 260-280 yards - 4 Iron - (TOTAL ATTEMPTS DIST RANGE)',
#  'Early Par 3 Scoring Average - (TOTAL STROKES)',
#  'Approaches from 100-125 yards - (TOTAL DISTANCE (FEET))',
#  'Average Approach Distance - Par - (AVG (YARDS))',
#  'Putting Average - (GIR PUTTS)',
#  'Distance Analysis 210-220 yards - 6 Iron - (ROUNDS)',
#  "Putting from 7' - (PUTTS MADE)",
#  'Approaches from 200-225 yards (Rgh) - (ROUNDS)',
#  'Driving Pct. 320+ (Measured) - (RELATIVE TO PAR)',
#  'Distance Analysis 210-220 yards - 4 Iron - (TOTAL ATTEMPTS WITH CLUB)',
#  'Distance Analysis 200-220 yards - Fairway Wood - (ROUNDS)',
#  'Distance Analysis < 80 yards - Wedges - (%)',
#  '% of Potential Pts won - FedExCup Playoffs - (# OF WINS)',
#  'Distance Analysis 120-130 yards - Fairway Wood - (TOTAL ATTEMPTS WITH CLUB)',
#  'Total Driving - (DISTANCE RANK)',
#  "GIR Putting - 10-15' - (PUTTS MADE)",
#  'Longest Putts - (ROUND)',
#  'Driving Pct. 240-260 (All Drives) - (TOTAL DRIVES - OVERALL)',
#  "3-Putt Avoidance - 10-15' - (ROUNDS)",
#  'Scoring Rating - (EVENTS)',
#  'Money Leaders - Fall Series - (MONEY)',
#  'Tenth Tee Late Par 5 Scoring Average - (ROUNDS)',
#  'Fairway Bunker Tendency - (TOTAL FAIRWAY BUNKERS)',
#  'Non-Member Off+WGC Earnings - (EVENTS)',
#  "Total 3 Putts - 10-15' - (ROUNDS)",
#  'Approach Putt Performance - (VALUE)',
#  'GIR Percentage - < 125 yards - (ROUNDS)',
#  "Putting from 3-5' - (ATTEMPTS)",
#  'Top 10 Final Round Performance - (EVENTS)',
#  'Distance Analysis 200-220 yards - 9 Iron - (%)',
#  'Distance Analysis 200-220 yards - 9 Iron - (TOTAL ATTEMPTS WITH CLUB)',
#  '3+ Putts per Round - (TOTAL 3+ PUTTS)',
#  'Distance Analysis 170-180 yards - 2 Iron - (TOTAL ATTEMPTS DIST RANGE)',
#  'Approaches from > 200 yards (Rgh) - (TOTAL DISTANCE (FEET))',
#  "Putting from 10' - (% MADE)",
#  'Approach 50-75 yards (RTP Score) - (ROUNDS)',
#  'Sand Saves from 30+ yards - (# OF SAVES)',
#  'Distance Analysis 150-160 yards - Wedges - (%)',
#  'Approaches from 125-150 yards (Rgh) - (# OF ATTEMPTS)',
#  'Distance Analysis 200-220 yards - 2 Iron - (TOTAL ATTEMPTS DIST RANGE)',
#  'Birdie or Better Percentage - (TOTAL BIRDIES)',
#  'Consecutive Sand Saves - (STREAK)',
#  'Distance Analysis < 80 yards - Fairway Wood - (TOTAL ATTEMPTS WITH CLUB)',
#  "3-Putt Avoidance - 5-10' - (2 PUTT OR BETTER %)",
#  'Approaches from > 200 yards - (ROUNDS)',
#  "Putting from 3' - (% MADE)",
#  'Approaches < 100 yards-Rgh (RTP) - (AVG RTP)',
#  'Approaches from 50-125 yards (Rgh) - (AVG)',
#  'Distance Analysis 180-190 yards - 2 Iron - (TOTAL ATTEMPTS DIST RANGE)',
#  'Consecutive GIR - (EVENTS)',
#  'Distance Analysis 260-280 yards - 6 Iron - (TOTAL ATTEMPTS WITH CLUB)',
#  'Distance Analysis 260-280 yards - 7 Iron - (TOTAL ATTEMPTS DIST RANGE)',
#  'Par 4 Performance - (PAR 4 AVG)',
#  'First Tee Late Par 4 Scoring Average - (TOTAL STROKES)',
#  'Average Distance of Eagle putts made - (AVG)',
#  'Hit Fairway Percentage - (FAIRWAYS HIT)',
#  "Putting from 15-25' - (ATTEMPTS)",
#  'Scrambling Fringe (RTP Score) - (TOTAL RTP)',
#  "FedExCup Playoffs Points - (# OF TOP 10'S)",
#  'Bogey Average - (ROUNDS PLAYED)',
#  'GIR Pct. - Fairway Bunker - (%)',
#  'Hang Time - (SHORTEST ACT. HANG TIME)',
#  'Birdie or Better Percentage - 125-150 yards - (TOTAL BIRDIES)',
#  "Putting from - 20-25' - (ROUNDS)",
#  'Approach 200-225 yards (RTP) - (AVG RTP)',
#  'SG: Tee-to-Green - (SG:ARG)',
#  'Proximity to Hole from < 10 yards - (TOTAL DISTANCE (FEET))',
#  'Average Putting Distance - GIR 3 Putts - (AVG)',
#  'Approaches 100-125 yards-Rgh (RTP) - (ROUNDS)',
#  'Total Money (Official and Unofficial) - (MONEY)',
#  'Distance Analysis 220-240 yards - 6 Iron - (TOTAL ATTEMPTS WITH CLUB)',
#  'Back 9 Par 3 Scoring Average - (AVG)',
#  'Par Breakers - (# BIRDIES/EAGLES)',
#  'FedExCup Points per Event Leaders - (POINTS PER EVENT)',
#  'FedExCup Playoffs Points - (POINTS)',
#  'Scrambling from > 30 yards - (ROUNDS)',
#  "Putting from 7' - (ATTEMPTS)",
#  'Distance Analysis 220-240 yards - 3 Iron - (%)',
#  'Tenth Tee Early Par 5 Scoring Average - (AVG)',
#  'Average Distance of Birdie putts made - (LONGEST MADE (FT))',
#  'Front 9 Par 4 Scoring Average - (TOTAL STROKES)',
#  "Putting from 9' - (ATTEMPTS)",
#  'Distance Analysis 200-220 yards - 8 Iron - (%)',
#  'Par 5 Scoring Average - (TOTAL HOLES)',
#  'Distance Analysis 180-190 yards - Wedges - (ROUNDS)',
#  'Birdie or Better Percentage - Left Rough - (TOTAL BIRDIES)',
#  'Distance Analysis 220-240 yards - 7 Iron - (TOTAL ATTEMPTS WITH CLUB)',
#  'Last 5 Events - Putting - (EVENTS)',
#  'Distance Analysis 210-220 yards - Driver - (TOTAL ATTEMPTS WITH CLUB)',
#  '% of Potential Pts won - FedExCup Playoffs - (PLAYOFF POINTS WON)',
#  'Distance Analysis 220-240 yards - 8 Iron - (TOTAL ATTEMPTS DIST RANGE)',
#  'Distance Analysis 240-260 yards - 3 Iron - (ROUNDS)',
#  'Average Putting Distance - All 3 putts - (AVG)',
#  'Distance Analysis 100-110 yards - 9 Iron - (TOTAL ATTEMPTS DIST RANGE)',
#  'Distance Analysis 200-210 yards - 7 Iron - (ROUNDS)',
#  'Longest Hole Outs (in yards) - (TOURNAMENT)',
#  'Front 9 Par 5 Scoring Average - (TOTAL STROKES)',
#  'First Tee Late Par 5 Scoring Average - (AVG)',
#  'Smash Factor - (LOWEST VALUE)',
#  'Birdie or Better Percentage - 175-200 yards - (%)',
#  'Distance Analysis 200-220 yards - 5 Iron - (ROUNDS)',
#  '1-Putts per Round - (TOTAL ROUNDS)',
#  'Distance Analysis 150-160 yards - Driver - (ROUNDS)',
#  'Birdie or Better Percentage - Left Rough - (ROUNDS)',
#  "Total 3 Putts - Inside 5' - (TOTAL 3 PUTTS INSIDE 5')",
#  'Club Head Speed - (TOTAL ATTEMPTS)',
#  'Front 9 Par 3 Scoring Average - (TOTAL STROKES)',
#  'First Tee Late Scoring Average - (ROUNDS)',
#  'Driving Pct. 280-300 (Measured) - (TOTAL DRVS - OVERALL)',
#  'Rough Tendency - (RELATIVE TO PAR)',
#  'Right Rough Tendency - (TOTAL RIGHT ROUGH)',
#  'FedExCup Playoffs Points - (EVENTS)',
#  'Distance Analysis 140-150 yards - Wedges - (%)',
#  'SG: Total - (AVERAGE)',
#  'GIR Percentage - 150-175 yards - (GREENS HIT)',
#  'Proximity to Hole from < 10 yards - (SCRAMBLING RANK)',
#  'Birdie or Better Percentage - Left Rough - (%)',
#  'Average Distance of Putts made - (AVG DIST.)',
#  'Tenth Tee Late Par 3 Scoring Average - (ROUNDS)',
#  'Apex Height - (LOWEST APEX POINT)',
#  'Distance Analysis 160-170 yards - 7 Iron - (TOTAL ATTEMPTS WITH CLUB)',
#  'Distance Analysis 110-120 yards - Fairway Wood - (%)',
#  "Total 3 Putts - 10-15' - (TOTAL 3 PUTTS)",
#  "3-Putt Avoidance - 15-20' - (TOTAL 3 PUTTS)",
#  'Total Distance Efficiency - (AVG.)',
#  "Putting from 3-5' - (PUTTS MADE)",
#  'Scrambling Rough (RTP Score) - (TOTAL HOLES)',
#  'Driving Pct. <= 240 (Measured) - (TOTAL DRVS - OVERALL)',
#  'Approaches > 275 yards-Rgh (RTP) - (ROUNDS)',
#  'Par 4 Eagle Leaders - (TOTAL)',
#  'Distance Analysis 220-240 yards - 7 Iron - (%)',
#  'Distance Analysis 210-220 yards - Driver - (TOTAL ATTEMPTS DIST RANGE)',
#  'SG: Total - (TOTAL SG:P)',
#  'Distance Analysis 150-160 yards - 7 Iron - (TOTAL ATTEMPTS WITH CLUB)',
#  'FedExCup Points per Event Leaders - (TOTAL POINTS)',
#  "Putting from - 20-25' - (PUTTS MADE)",
#  'Sand Saves from 20-30 yards - (ROUNDS)',
#  "GIR Putting Avg - 25-30' - (PUTTS MADE)",
#  'Distance Analysis < 80 yards - 2 Iron - (TOTAL ATTEMPTS WITH CLUB)',
#  'Putts Per Round - (TOTAL PUTTS)',
#  'Approaches from inside 100 yards - (AVG)',
#  'GIR Percentage - < 125 yards - (%)',
#  'Front 9 Par 5 Scoring Average - (TOTAL HOLES)',
#  'Hit Fairway Percentage - (POSSIBLE FAIRWAYS)',
#  'Distance Analysis 190-200 yards - 7 Iron - (TOTAL ATTEMPTS WITH CLUB)',
#  'Sand Saves from 10-20 yards - (# OF SAVES)',
#  'Distance Analysis 210-220 yards - 7 Iron - (TOTAL ATTEMPTS WITH CLUB)',
#  'Approaches from 150-175 yards (Rgh) - (# OF ATTEMPTS)',
#  'Par 5 Performance - (STATUS)',
#  "Putting from - 10-15' - (PUTTS MADE)",
#  'Distance Analysis 210-220 yards - 9 Iron - (TOTAL ATTEMPTS DIST RANGE)',
#  'Distance Analysis 140-150 yards - Driver - (%)',
#  'Distance Analysis 130-140 yards - Wedges - (%)',
#  'Approaches from > 100 yards - (ROUNDS)',
#  'Carry Distance - (TOTAL ATTEMPTS)',
#  'FedExCup Standings - (EVENTS)',
#  'Left Rough Proximity - (RELATIVE TO PAR)',
#  'Going for the Green - (ROUNDS)',
#  'Back 9 Par 4 Scoring Average - (ROUNDS)',
#  "3-Putt Avoidance - 10-15' - (ATTEMPTS)",
#  'Distance Analysis 160-170 yards - 3 Iron - (ROUNDS)',
#  "Total 3 Putts - 5-10' - (ROUNDS)",
#  'Current Par or Better Streak - (EVENTS)',
#  'Distance Analysis 110-120 yards - 9 Iron - (TOTAL ATTEMPTS WITH CLUB)',
#  'Spin Rate - (AVG.)',
#  "Putting from - 15-20' - (PUTTS MADE)",
#  'Right Rough Proximity - (TOTAL DISTANCE (FEET))',
#  'Scoring Average - (ROUNDS)',
#  'Distance Analysis 180-190 yards - 7 Iron - (TOTAL ATTEMPTS DIST RANGE)',
#  'Carry Distance - (TOTAL DIST. TO IMPACT)',
#  "Putting from 3-5' - (% MADE)",
#  'SG: Tee-to-Green - (SG:OTT)',
#  'Rough Proximity - (ATTEMPTS)',
#  'Left Tendency - (%)',
#  'Putting Rating - (EVENTS)',
#  "Total 1 Putts - Inside 5' - (ROUNDS)",
#  'Approaches from > 200 yards (Rgh) - (ROUNDS)',
#  'Approaches from 150-175 yards - (ROUNDS)',
#  'Proximity to Hole - (AVG)',
#  'Distance Analysis 190-200 yards - 3 Iron - (%)',
#  'Approaches Right Rough (RTP Score) - (AVG RTP)',
#  "Putting from Inside 5' - (%)",
#  'Launch Angle - (TOTAL ATTEMPTS)',
#  'Club Head Speed - (TOTAL CLUB HEAD SPEED)',
#  'Rough Tendency - (%)',
#  'First Tee Early Scoring Average - (ROUNDS)',
#  'SG: Total - (ROUNDS)',
#  'Distance Analysis 120-130 yards - Wedges - (ROUNDS)',
#  'GIR Percentage - 125-150 yards - (RELATIVE TO PAR)',
#  'Average Approach Distance - Birdie or Better - (ROUNDS)',
#  'Sand Saves from 30+ yards - (# OF BUNKERS)',
#  "Putting from 5' - (ATTEMPTS)",
#  'First Tee Late Par 3 Scoring Average - (TOTAL STROKES)',
#  'Distance Analysis 200-220 yards - Fairway Wood - (%)',
#  'Right Rough Tendency - (ROUNDS)',
#  'Distance Analysis 170-180 yards - 8 Iron - (ROUNDS)',
#  "Total 3 Putts - 15-20' - (TOTAL 3 PUTTS 15'-20')",
#  'Distance Analysis 160-170 yards - Driver - (%)',
#  'Distance Analysis 160-170 yards - Fairway Wood - (ROUNDS)',
#  'Going for the Green - Hit Green Pct. - (ATTEMPTS)',
#  'Average Putting Distance - GIR 2 Putts - (AVG)',
#  'Distance Analysis 110-120 yards - Wedges - (TOTAL ATTEMPTS WITH CLUB)',
#  'Scrambling from the Sand - (SUCCESSES)',
#  'Sand Saves from 10-20 yards - (ROUNDS)',
#  'Distance Analysis 200-220 yards - 2 Iron - (TOTAL ATTEMPTS WITH CLUB)',
#  'FedExCup Playoffs Points - (# OF WINS)',
#  'Birdie Average - (ROUNDS)',
#  'Top 10 Final Round Performance - (# OF TIMES IMPROVED)',
#  'Distance Analysis 170-180 yards - Fairway Wood - (ROUNDS)',
#  'Ball Speed - (TOTAL ATTEMPTS)',
#  'Distance Analysis 120-130 yards - Fairway Wood - (TOTAL ATTEMPTS DIST RANGE)',
#  'Putts made Distance - (EVENTS)',
#  'Approaches from 175-200 yards (Rgh) - (TOTAL DISTANCE (FEET))',
#  'Distance Analysis 150-160 yards - 5 Iron - (TOTAL ATTEMPTS DIST RANGE)',
#  'Distance Analysis 180-190 yards - 3 Iron - (TOTAL ATTEMPTS WITH CLUB)',
#  'Approaches from 50-125 yards (Rgh) - (RELATIVE TO PAR)',
#  'Driving Pct. 300-320 (All Drives) - (%)',
#  'Approaches from 200-225 yards - (# OF ATTEMPTS)',
#  'Distance Analysis 100-110 yards - 5 Iron - (TOTAL ATTEMPTS WITH CLUB)',
#  'Top 10 Finishes - (3RD)',
#  'Driving Pct. <= 240 (All Drives) - (%)',
#  'Approaches from > 275 yards - (RELATIVE TO PAR)',
#  'Approaches from 250-275 yards (Rgh) - (AVG)',
#  'Distance Analysis 110-120 yards - Driver - (TOTAL ATTEMPTS DIST RANGE)',
#  'Distance Analysis 220-240 yards - 8 Iron - (ROUNDS)',
#  'Approaches from 225-250 yards - (# OF ATTEMPTS)',
#  'Distance Analysis 220-240 yards - 2 Iron - (%)',
#  'GIR Percentage - 175-200 yards - (GREENS HIT)',
#  'Scrambling 10-20 yds (RTP Score) - (TOTAL RTP)',
#  'Average Putting Distance - GIR 1 Putts - (DISTANCE (FEET))',
#  "3-Putt Avoidance - 5-10' - (ROUNDS)",
#  'SG: Putting - (ROUNDS)',
#  'Greens or Fringe in Regulation - (TOTAL ATTEMPTS)',
#  'Carry Distance - (SHORTEST CARRY DISTANCE)',
#  'Distance Analysis 170-180 yards - 2 Iron - (TOTAL ATTEMPTS WITH CLUB)',
#  'Driving Pct. 260-280 (All Drives) - (%)',
#  'Approaches from 250-275 yards - (AVG)',
#  'Driving Pct. 280-300 (All Drives) - (RELATIVE TO PAR)',
#  'Missed Fairway Percent - Other - (%)',
#  'Distance Analysis 180-190 yards - 9 Iron - (TOTAL ATTEMPTS DIST RANGE)',
#  'Distance Analysis 190-200 yards - Driver - (TOTAL ATTEMPTS DIST RANGE)',
#  'Distance Analysis 260-280 yards - 7 Iron - (%)',
#  'Distance Analysis 200-210 yards - Driver - (ROUNDS)',
#  "GIR Putting - 5-10' - (%)",
#  "Putting from 5' - (PUTTS MADE)",
#  'Birdie or Better Percentage - < 125 yards - (%)',
#  "Putting from - 15-20' - (ROUNDS)",
#  'Tenth Tee Early Par 4 Scoring Average - (AVG)',
#  'Longest Hole Outs (in yards) - (DISTANCE)',
#  'Distance Analysis 200-210 yards - 7 Iron - (TOTAL ATTEMPTS WITH CLUB)',
#  'FedExCup Standings - (POINTS BEHIND LEAD)',
#  'Rough Proximity - (RELATIVE TO PAR)',
#  'Scrambling from the Sand - (ROUNDS)',
#  'Birdie Average - (# OF BIRDIES)',
#  'GIR Pct. - Fairway Bunker - (ROUNDS)',
#  "Putting from 8' - (ATTEMPTS)",
#  'GIR Percentage - 125-150 yards - (ROUNDS)',
#  'Scrambling from the Fringe - (ROUNDS)',
#  'Total Driving Efficiency - (COMBINED RANK)',
#  'One-Putt Percentage - Round 1 - (%)',
#  'Birdie or Better Percentage - Rough - (TOTAL BIRDIES)',
#  'First Tee Late Par 4 Scoring Average - (TOTAL HOLES)',
#  '1-Putts per Round - (TOTAL 1 PUTTS)',
#  'Distance Analysis 160-170 yards - 4 Iron - (%)',
#  'Birdie or Better Percentage - Right Rough - (%)',
#  'Driving Pct. 300-320 (All Drives) - (ROUNDS)',
#  'Scoring Average (Actual) - (ROUNDS)',
#  "3-Putt Avoidance - 20-25' - (%)",
#  'Average Distance of Birdie putts made - (SHORTEST MADE (FT))',
#  'World Golf Ranking Points - (EVENTS)',
#  'Proximity to Hole (ARG) - (# OF SHOTS)',
#  'Consecutive Par 5 Birdies - (NUMBER OF HOLES)',
#  'Average Approach Shot Distance - (AVG)',
#  'GIR Percentage - < 75 yards - (GREENS HIT)',
#  'Approaches from 125-150 yards - (ROUNDS)',
#  'Distance Analysis 180-190 yards - Fairway Wood - (TOTAL ATTEMPTS DIST RANGE)',
#  'Approaches from 50-75 yards (Rgh) - (TOTAL DISTANCE (FEET))',
#  'Approach Putt Performance - (TOTAL DISTANCE (FEET))',
#  'Back 9 Scoring Average - (TOTAL HOLES)',
#  "Total 1 Putts - 15-20' - (PCT OF ALL 1-PUTTS)",
#  'Distance Analysis 110-120 yards - 7 Iron - (%)',
#  'Best YTD Streak w/o a 3-Putt - (CURRENT STREAK)',
#  'Hang Time - (TOTAL ACTUAL HANG TIME)',
#  'Distance Analysis 100-110 yards - Wedges - (ROUNDS)',
#  'Scrambling from the Fringe - (SUCCESSES)',
#  "GIR Putting - Inside 5' - (ATTEMPTS)",
#  'Driving Pct. 300-320 (Measured) - (TOTAL DRIVES FOR 300-320)',
#  'First Tee Early Par 4 Scoring Average - (AVG)',
#  'Distance Analysis 260-280 yards - 7 Iron - (TOTAL ATTEMPTS WITH CLUB)',
#  'Distance Analysis 140-150 yards - 6 Iron - (TOTAL ATTEMPTS DIST RANGE)',
#  'Greens or Fringe in Regulation - (TOTAL HIT)',
#  'First Tee Late Lowest Round - (LOW RND)',
#  'Approaches from 200-225 yards - (AVG)',
#  'Right Rough Tendency - (%)',
#  'Approaches from 75-100 yards - (AVG)',
#  'Distance Analysis 180-190 yards - Wedges - (TOTAL ATTEMPTS WITH CLUB)',
#  'GIR Percentage from Fairway - (ROUNDS)',
#  'Par 4 Eagle Leaders - (TOTAL PAR 4 HOLES)',
#  'Distance Analysis 110-120 yards - Wedges - (%)',
#  "GIR Putting - > 25' - (PUTTS MADE)",
#  'Left Rough Tendency (RTP Score) - (RTP SCORE)',
#  'Distance Analysis 190-200 yards - 5 Iron - (TOTAL ATTEMPTS WITH CLUB)',
#  'Putts Per Round - (ROUNDS)',
#  'Distance Analysis 130-140 yards - 8 Iron - (TOTAL ATTEMPTS DIST RANGE)',
#  'Approach > 275 yards (RTP) - (ROUNDS)',
#  'Total Distance Efficiency - (AVERAGE CLUB HEAD SPEED)',
#  'Average Putting Distance - GIR 3 Putts - (DISTANCE (FEET))',
#  "Total 1 Putts - Inside 5' - (TOTAL (FOR ALL DISTANCES))",
#  'Distance Analysis 130-140 yards - 4 Iron - (TOTAL ATTEMPTS DIST RANGE)',
#  '11-25 Final Round Performance - (% TIMES IMPROVED)',
#  "Total 1 Putts - 20-25' - (ROUNDS)",
#  'Par 5 Scoring Average - (ROUNDS)',
#  'Front 9 Scoring Average - (AVG)',
#  'Distance Analysis 170-180 yards - 7 Iron - (%)',
#  'Approaches from 250-275 yards - (# OF ATTEMPTS)',
#  'Distance Analysis 240-260 yards - 6 Iron - (TOTAL ATTEMPTS DIST RANGE)',
#  'Approaches from 250-275 yards (Rgh) - (# OF ATTEMPTS)',
#  'Driving Pct. 300+ (All Drives) - (ROUNDS)',
#  'SG: Total - (TOTAL SG:T)',
#  'First Tee Late Par 3 Scoring Average - (TOTAL HOLES)',
#  'Birdie or Better Percentage - Rough - (TOTAL HOLES)',
#  'Sand Save Percentage - (TOTAL O/U PAR)',
#  'Reverse Bounce Back - (ROUNDS)',
#  'Distance Analysis 180-190 yards - 4 Iron - (ROUNDS)',
#  'Driving Pct. 240-260 (Measured) - (TOTAL DRIVES FOR 240-260)',
#  'Average Putting Distance - GIR 2 Putts - (DISTANCE (FEET))',
#  'Distance Analysis 120-130 yards - 9 Iron - (TOTAL ATTEMPTS WITH CLUB)',
#  'Distance Analysis < 80 yards - Fairway Wood - (TOTAL ATTEMPTS DIST RANGE)',
#  'Late Par 4 Scoring Average - (ROUNDS)',
#  'Average Distance of Putts made - (AVG)',
#  'Longest Hole Outs (in yards) - (HOLE)',
#  "3-Putt Avoidance - Inside 5' - (ATTEMPTS)",
#  'Driving Distance - All Drives - (ROUNDS)',
#  'Distance Analysis 170-180 yards - Driver - (%)',
#  'Distance Analysis 170-180 yards - 6 Iron - (%)',
#  'Launch Angle - (AVG.)',
#  'Consecutive Sand Saves - (HOLE)',
#  'Carry Distance - (AVG.)',
#  'Official World Golf Ranking - (COUNTRY)',
#  'Approaches from > 275 yards - (TOTAL DISTANCE (FEET))',
#  'Distance Analysis 220-240 yards - 5 Iron - (TOTAL ATTEMPTS WITH CLUB)',
#  'Distance Analysis 160-170 yards - 5 Iron - (ROUNDS)',
#  'Driving Pct. 260-280 (All Drives) - (TOTAL DRIVES - OVERALL)',
#  '2019 PGA Championship Points - (EVENTS)',
#  'Distance to Apex - (TOTAL APEX RANGE)',
#  'Distance Analysis 220-240 yards - Wedges - (ROUNDS)',
#  'Last 5 Events - Accuracy - (RATING)',
#  'Driving Pct. 300+ (Measured) - (TOTAL DRIVES FOR 300+)',
#  'Driving Accuracy Percentage - (POSSIBLE FAIRWAYS)',
#  'Consecutive GIR - (HOLE)',
#  'Reverse Bounce Back - (TOTAL UNDER THEN OVER PAR)',
#  'Birdie or Better Percentage - 175-200 yards - (ROUNDS)',
#  'Distance Analysis 200-220 yards - 7 Iron - (ROUNDS)',
#  'Birdie or Better Percentage - (TOTAL HOLES)',
#  'Longest Drives - (ROUND)',
#  'Distance Analysis 210-220 yards - 8 Iron - (ROUNDS)',
#  'Rough Proximity - (ROUNDS)',
#  'First Tee Early Par 3 Scoring Average - (TOTAL HOLES)',
#  'Approaches from 125-150 yards - (RELATIVE TO PAR)',
#  'World Money List - (MONEY)',
#  "Total 1 Putts - 15-20' - (TOTAL)",
#  'Distance Analysis 210-220 yards - 2 Iron - (ROUNDS)',
#  'Distance Analysis 190-200 yards - 5 Iron - (%)',
#  "GIR Putting - > 25' - (%)",
#  'Approaches 75-100 yards-Rgh (RTP) - (AVG RTP)',
#  "Putting from 4' - (ATTEMPTS)",
#  'Distance Analysis 130-140 yards - 8 Iron - (TOTAL ATTEMPTS WITH CLUB)',
#  "Putting from 4-8' - (ROUNDS)",
#  'Approaches from 100-125 yards - (RELATIVE TO PAR)',
#  'Distance Analysis 110-120 yards - 7 Iron - (TOTAL ATTEMPTS DIST RANGE)',
#  'Distance Analysis 160-170 yards - 3 Iron - (TOTAL ATTEMPTS DIST RANGE)',
#  'Distance Analysis 220-240 yards - Fairway Wood - (TOTAL ATTEMPTS DIST RANGE)',
#  'Club Head Speed - (ROUNDS)',
#  'Late Par 3 Scoring Average - (TOTAL STROKES)',
#  'Average Distance of Eagle putts made - (ROUNDS)',
#  'Sand Saves from 20-30 yards - (%)',
#  'Driving Pct. 260-280 (All Drives) - (ROUNDS)',
#  'Par 4 Scoring Average - (ROUNDS)',
#  'Consecutive GIR - (STREAK)',
#  'Fairway Approach (RTP Score) - (AVG RTP)',
#  'Total Driving - (EVENTS)',
#  'Spin Rate - (TOTAL ATTEMPTS)',
#  'Distance Analysis 210-220 yards - 9 Iron - (%)',
#  'Distance Analysis 190-200 yards - 3 Iron - (ROUNDS)',
#  'Distance Analysis 160-170 yards - 9 Iron - (TOTAL ATTEMPTS WITH CLUB)',
#  'Par 5 Eagle Leaders - (TOTAL PAR 5 HOLES)',
#  'Distance Analysis 170-180 yards - 4 Iron - (TOTAL ATTEMPTS DIST RANGE)',
#  'GIR Percentage - < 125 yards - (RELATIVE TO PAR)',
#  "Total 1 Putts - Inside 5' - (TOTAL)",
#  'Scrambling - (PAR OR BETTER)',
#  "3-Putt Avoidance > 25' - (%)",
#  'Driving Pct. 260-280 (All Drives) - (TOTAL DRIVES FOR 260-280)',
#  'Distance Analysis 170-180 yards - Wedges - (%)',
#  'Distance Analysis 190-200 yards - Fairway Wood - (TOTAL ATTEMPTS DIST RANGE)',
#  'First Tee Early Par 5 Scoring Average - (ROUNDS)',
#  'Average Approach Distance - Par - (NUMBER OF APPROACH SHOTS)',
#  'Driving Pct. 300+ (Measured) - (ROUNDS)',
#  "Putting from Inside 5' - (PUTTS MADE)",
#  'Average Approach Distance - Bogey or Worse - (ROUNDS)',
#  'Right Rough Tendency (RTP Score) - (RTP SCORE)',
#  'Missed Fairway Percent - Other - (RELATIVE TO PAR)',
#  'Approaches from 100-125 yards (Rgh) - (TOTAL DISTANCE (FEET))',
#  'Approaches from 50-125 yards (Rgh) - (ROUNDS)',
#  'Tenth Tee Late Par 3 Scoring Average - (TOTAL HOLES)',
#  'Distance Analysis 200-210 yards - 4 Iron - (TOTAL ATTEMPTS DIST RANGE)',
#  'One-Putt Percentage - (%)',
#  "Percentage of Yardage covered by Tee Shots - Par 4's - (AVG (%))",
#  'Approaches from 100-125 yards (Rgh) - (RELATIVE TO PAR)',
#  'Apex Height - (AVG.)',
#  'Stroke Differential Field Average - (ROUNDS)',
#  'Tenth Tee Late Par 3 Scoring Average - (AVG)',
#  'Tenth Tee Late Par 5 Scoring Average - (TOTAL STROKES)',
#  'Distance to Apex - (TOTAL ATTEMPTS)',
#  'Distance Analysis 190-200 yards - 6 Iron - (ROUNDS)',
#  'Distance Analysis 220-240 yards - Wedges - (TOTAL ATTEMPTS DIST RANGE)',
#  'Approaches from 75-100 yards (Rgh) - (# OF ATTEMPTS)',
#  'Par 5 Birdie or Better Leaders - (PAR 5 HOLES)',
#  "Putting - Inside 10' - (% MADE)",
#  'Par 4 Birdie or Better Leaders - (%)',
#  'Proximity to Hole from 10-20 yards - (TOTAL DISTANCE (FEET))',
#  "3-Putt Avoidance > 25' - (ROUNDS)",
#  'Hit Fairway Percentage - (%)',
#  'Last 5 Events - Scoring - (RATING)',
#  'Approaches 50-75 yards-Rgh (RTP) - (AVG RTP)',
#  'Birdie or Better Percentage - 150-175 yards - (TOTAL BIRDIES)',
#  'Distance Analysis 170-180 yards - 8 Iron - (%)',
#  'Scrambling 10-20 yds (RTP Score) - (ROUNDS)',
#  'First Tee Early Lowest Round - (LOW RND)',
#  'Scrambling from 20-30 yards - (SUCCESSES)',
#  'Distance Analysis 160-170 yards - 3 Iron - (TOTAL ATTEMPTS WITH CLUB)',
#  ...}

# %%
golf.Statistic.unique()
# Out:
# array(['Driving Distance', 'Driving Accuracy Percentage',
#        'Greens in Regulation Percentage', 'Putting Average',
#        'Par Breakers', 'Total Eagles', 'Total Birdies',
#        'Scoring Average (Actual)', 'Money Leaders',
#        'Sand Save Percentage', 'Par 3 Birdie or Better Leaders',
#        'Par 4 Birdie or Better Leaders', 'Par 5 Birdie or Better Leaders',
#        'Birdie or Better Conversion Percentage', 'Putts Per Round',
#        'Scoring Average', 'All-Around Ranking', 'Total Driving',
#        'Scrambling', 'Ryder Cup Points', 'PGA Championship Points',
#        'Putts made Distance', 'Top 10 Finishes', 'Non-member Earnings',
#        'Par 3 Scoring Average', 'Par 4 Scoring Average',
#        'Par 5 Scoring Average', "3-Putt Avoidance - 15-20'",
#        "3-Putt Avoidance - 20-25'", "3-Putt Avoidance > 25'",
#        'Current Par or Better Streak', "Rounds in the 60's",
#        'Money per Event Leaders', 'Eagles (Holes per)', 'Birdie Average',
#        'World Money List', 'Ball Striking', 'Longest Drives',
#        'Bounce Back', 'Par 3 Performance', 'Par 4 Performance',
#        'Par 5 Performance', 'World Golf Ranking Points',
#        'Official World Golf Ranking', 'Presidents Cup (International)',
#        'Money Ldrs /w/WGC Non-Mbr Money', 'GIR Percentage from Fairway',
#        'Total Money (Official and Unofficial)',
#        'GIR Percentage from Other than Fairway',
#        'Front 9 Scoring Average', 'Back 9 Scoring Average',
#        'First Tee Early Scoring Average',
#        'Tenth Tee Early Scoring Average',
#        'First Tee Late Scoring Average', 'Tenth Tee Late Scoring Average',
#        'Hit Fairway Percentage', 'Driving Pct. 300+ (All Drives)',
#        'Driving Pct. 280-300 (All Drives)',
#        'Driving Pct. 260-280 (All Drives)',
#        'Driving Pct. 240-260 (All Drives)',
#        'Driving Pct. <= 240 (All Drives)', 'Final Round Performance',
#        'Top 10 Final Round Performance', 'Front 9 Par 3 Scoring Average',
#        'Back 9 Par 3 Scoring Average', 'Early Par 3 Scoring Average',
#        'Late Par 3 Scoring Average',
#        'First Tee Early Par 3 Scoring Average',
#        'Tenth Tee Early Par 3 Scoring Average',
#        'First Tee Late Par 3 Scoring Average',
#        'Tenth Tee Late Par 3 Scoring Average',
#        'Front 9 Par 4 Scoring Average', 'Back 9 Par 4 Scoring Average',
#        'Early Par 4 Scoring Average', 'Late Par 4 Scoring Average',
#        'First Tee Early Par 4 Scoring Average',
#        'Tenth Tee Early Par 4 Scoring Average',
#        'First Tee Late Par 4 Scoring Average',
#        'Tenth Tee Late Par 4 Scoring Average',
#        'Front 9 Par 5 Scoring Average', 'Back 9 Par 5 Scoring Average',
#        'Early Par 5 Scoring Average', 'Late Par 5 Scoring Average',
#        'First Tee Early Par 5 Scoring Average',
#        'Tenth Tee Early Par 5 Scoring Average',
#        'First Tee Late Par 5 Scoring Average',
#        'Tenth Tee Late Par 5 Scoring Average', 'Early Scoring Average',
#        'Late Scoring Average', 'Best YTD Streak w/o a 3-Putt',
#        'Best YTD 1-Putt or Better Streak', 'Consecutive Sand Saves',
#        'Consecutive Fairways Hit', 'Consecutive GIR', 'Lowest Round',
#        'Victory Leaders', 'Back 9 Lowest Round',
#        'First Tee Early Lowest Round', 'Tenth Tee Early Lowest Round',
#        'First Tee Late Lowest Round', 'Tenth Tee Late Lowest Round',
#        'Top 5 Final Round Performance', '11-25 Final Round Performance',
#        '25+ Final Round Performance', 'Driving Distance - All Drives',
#        'GIR Percentage - 200+ yards', 'GIR Percentage - 175-200 yards',
#        'GIR Percentage - 150-175 yards', 'GIR Percentage - 125-150 yards',
#        'GIR Percentage - < 125 yards', 'Proximity to Hole',
#        'Approaches from > 200 yards', 'Approaches from 175-200 yards',
#        'Approaches from 150-175 yards', 'Approaches from 125-150 yards',
#        'Approaches from 50-125 yards', "Putting from 3'",
#        "Putting from 4'", "Putting from 5'", "Putting from 6'",
#        "Putting from 7'", "Putting from 8'", "Putting from 9'",
#        "Putting from 10'", 'Approach Putt Performance', 'Total Hole Outs',
#        'Longest Hole Outs (in yards)', 'Birdie or Better Percentage',
#        "Putting from - > 10'", 'Birdie or Better Percentage - 200+ yards',
#        'Birdie or Better Percentage - 175-200 yards',
#        'Birdie or Better Percentage - 150-175 yards',
#        'Birdie or Better Percentage - 125-150 yards',
#        'Birdie or Better Percentage - < 125 yards',
#        'Scrambling from the Sand', 'Scrambling from the Rough',
#        'Scrambling from the Fringe', 'Scrambling from Other Locations',
#        'Scrambling from > 30 yards', 'Scrambling from 20-30 yards',
#        'Scrambling from 10-20 yards', 'Scrambling from < 10 yards',
#        'Sand Saves from 30+ yards', 'Sand Saves from 20-30 yards',
#        'Sand Saves from 10-20 yards', 'Sand Saves from < 10 yards',
#        'Proximity to Hole (ARG)', 'Proximity to Hole from Sand',
#        'Proximity to Hole from Rough', 'Proximity to Hole from Fringe',
#        'Proximity to Hole from Other Locations',
#        'Proximity to Hole from 30+ yards',
#        'Proximity to Hole from 20-30 yards',
#        'Proximity to Hole from 10-20 yards',
#        'Proximity to Hole from < 10 yards', "GIR Putting - Inside 5'",
#        "GIR Putting - 5-10'", "GIR Putting - 10-15'",
#        "GIR Putting - 15-20'", "GIR Putting - 20-25'",
#        "GIR Putting - > 25'", 'Average Putting Distance - GIR 1 Putts',
#        'Average Putting Distance - GIR 2 Putts',
#        'Average Putting Distance - GIR 3 Putts',
#        'Average Putting Distance - GIR 3+ Putts', '1-Putts per Round',
#        '2-Putts per Round', '3-Putts per Round', '3+ Putts per Round',
#        'Overall Putting Average', "Putting from Inside 5'",
#        "Putting from 5-10'", "Putting from - 10-15'",
#        "Putting from - 15-20'", "Putting from - 20-25'",
#        "Putting from - > 25'", 'Average Putting Distance - All 1 putts',
#        'Average Putting Distance - All 2 putts',
#        'Average Putting Distance - All 3 putts',
#        'Average Putting Distance - All 3+ putts', 'One-Putt Percentage',
#        'One-Putt Percentage - Round 1', 'Going for the Green',
#        "Total 1 Putts - Inside 5'", "Total 1 Putts - 5-10'",
#        "Total 1 Putts - 10-15'", "Total 1 Putts - 15-20'",
#        "Total 1 Putts - 20-25'", "Total 1 Putts - > 25'",
#        '3-Putt Avoidance', 'Fairway Proximity', 'Left Rough Proximity',
#        'Right Rough Proximity', "Putts Made Per Event Over 10'",
#        "Putts Made Per Event Over 20'", 'Par 5 Going for the Green',
#        'Rough Proximity', 'Average Distance of Putts made',
#        "Total 3 Putts - Inside 5'", "Total 3 Putts - 5-10'",
#        "Total 3 Putts - 10-15'", "Total 3 Putts - 15-20'",
#        "Total 3 Putts - 20-25'", "Total 3 Putts - > 25'",
#        'Par 4 Eagle Leaders', 'Par 5 Eagle Leaders',
#        'Consecutive Par 3 Birdies', 'Consecutive Par 4 Birdies',
#        'Consecutive Par 5 Birdies', 'Consecutive Holes Below Par',
#        '6-10 Final Round Performance', 'Driving Pct. 300+ (Measured)',
#        'Driving Pct. 280-300 (Measured)',
#        'Driving Pct. 260-280 (Measured)',
#        'Driving Pct. 240-260 (Measured)',
#        'Driving Pct. <= 240 (Measured)', 'Left Rough Tendency',
#        'Right Rough Tendency', 'Missed Fairway Percent - Other',
#        'Scrambling Rough (RTP Score)', 'Scrambling Fringe (RTP Score)',
#        'Scrambling > 30 yds (RTP Score)',
#        'Scrambling 20-30 yds (RTP Score)',
#        'Scrambling 10-20 yds (RTP Score)',
#        'Approaches Left Rough (RTP Score)',
#        'Approaches Right Rough (RTP Score)',
#        'Fairway Approach (RTP Score)', 'Approach < 125 yards (RTP Score)',
#        'Approach 125-150 yards (RTP Score)',
#        'Approach 150-175 yards (RTP Score)',
#        'Approach 175-200 yards (RTP Score)',
#        'Approach > 200 yards (RTP Score)',
#        'Scrambling Average Distance to Hole',
#        'Current Streak without a 3-Putt', "Putting - Inside 10'",
#        "Putting from 4-8'", 'Going for the Green - Hit Green Pct.',
#        'Driving Pct. 300-320 (Measured)', 'Driving Pct. 320+ (Measured)',
#        'Longest Putts', 'Distance Analysis 260-280 yards - 3 Iron',
#        'Distance Analysis 260-280 yards - 4 Iron',
#        'Distance Analysis 260-280 yards - 5 Iron',
#        'Distance Analysis 260-280 yards - 6 Iron',
#        'Distance Analysis 260-280 yards - 7 Iron',
#        'Distance Analysis 260-280 yards - 8 Iron',
#        'Distance Analysis 240-260 yards - Fairway Wood',
#        'Distance Analysis 240-260 yards - 2 Iron',
#        'Distance Analysis 240-260 yards - 3 Iron',
#        'Distance Analysis 240-260 yards - 4 Iron',
#        'Distance Analysis 240-260 yards - 5 Iron',
#        'Distance Analysis 240-260 yards - 6 Iron',
#        'Distance Analysis 240-260 yards - 7 Iron',
#        'Distance Analysis 240-260 yards - 8 Iron',
#        'Distance Analysis 240-260 yards - 9 Iron',
#        'Distance Analysis 240-260 yards - Wedges',
#        'Distance Analysis 220-240 yards - Driver',
#        'Distance Analysis 220-240 yards - Fairway Wood',
#        'Distance Analysis 220-240 yards - 2 Iron',
#        'Distance Analysis 220-240 yards - 3 Iron',
#        'Distance Analysis 220-240 yards - 4 Iron',
#        'Distance Analysis 220-240 yards - 5 Iron',
#        'Distance Analysis 220-240 yards - 6 Iron',
#        'Distance Analysis 220-240 yards - 7 Iron',
#        'Distance Analysis 220-240 yards - 8 Iron',
#        'Distance Analysis 220-240 yards - Wedges',
#        'Distance Analysis 200-220 yards - Driver',
#        'Distance Analysis 200-220 yards - Fairway Wood',
#        'Distance Analysis 200-220 yards - 2 Iron',
#        'Distance Analysis 200-220 yards - 3 Iron',
#        'Distance Analysis 200-220 yards - 4 Iron',
#        'Distance Analysis 200-220 yards - 5 Iron',
#        'Distance Analysis 200-220 yards - 6 Iron',
#        'Distance Analysis 200-220 yards - 7 Iron',
#        'Distance Analysis 200-220 yards - 8 Iron',
#        'Distance Analysis 200-220 yards - 9 Iron',
#        'Distance Analysis 200-220 yards - Wedges',
#        'Distance Analysis 210-220 yards - Driver',
#        'Distance Analysis 210-220 yards - Fairway Wood',
#        'Distance Analysis 210-220 yards - 2 Iron',
#        'Distance Analysis 210-220 yards - 3 Iron',
#        'Distance Analysis 210-220 yards - 4 Iron',
#        'Distance Analysis 210-220 yards - 5 Iron',
#        'Distance Analysis 210-220 yards - 6 Iron',
#        'Distance Analysis 210-220 yards - 7 Iron',
#        'Distance Analysis 210-220 yards - 8 Iron',
#        'Distance Analysis 210-220 yards - 9 Iron',
#        'Distance Analysis 210-220 yards - Wedges',
#        'Distance Analysis 200-210 yards - Fairway Wood',
#        'Distance Analysis 200-210 yards - 2 Iron',
#        'Distance Analysis 200-210 yards - 3 Iron',
#        'Distance Analysis 200-210 yards - 4 Iron',
#        'Distance Analysis 200-210 yards - 5 Iron',
#        'Distance Analysis 200-210 yards - 6 Iron',
#        'Distance Analysis 200-210 yards - 7 Iron',
#        'Distance Analysis 190-200 yards - Fairway Wood',
#        'Distance Analysis 190-200 yards - 2 Iron',
#        'Distance Analysis 190-200 yards - 3 Iron',
#        'Distance Analysis 190-200 yards - 4 Iron',
#        'Distance Analysis 190-200 yards - 5 Iron',
#        'Distance Analysis 190-200 yards - 6 Iron',
#        'Distance Analysis 190-200 yards - 7 Iron',
#        'Distance Analysis 190-200 yards - 8 Iron',
#        'Distance Analysis 190-200 yards - 9 Iron',
#        'Distance Analysis 180-190 yards - Driver',
#        'Distance Analysis 180-190 yards - Fairway Wood',
#        'Distance Analysis 180-190 yards - 2 Iron',
#        'Distance Analysis 180-190 yards - 3 Iron',
#        'Distance Analysis 180-190 yards - 4 Iron',
#        'Distance Analysis 180-190 yards - 5 Iron',
#        'Distance Analysis 180-190 yards - 6 Iron',
#        'Distance Analysis 180-190 yards - 7 Iron',
#        'Distance Analysis 180-190 yards - 8 Iron',
#        'Distance Analysis 180-190 yards - 9 Iron',
#        'Distance Analysis 180-190 yards - Wedges',
#        'Distance Analysis 170-180 yards - Driver',
#        'Distance Analysis 170-180 yards - Fairway Wood',
#        'Distance Analysis 170-180 yards - 2 Iron',
#        'Distance Analysis 170-180 yards - 3 Iron',
#        'Distance Analysis 170-180 yards - 4 Iron',
#        'Distance Analysis 170-180 yards - 6 Iron',
#        'Distance Analysis 170-180 yards - 7 Iron',
#        'Distance Analysis 170-180 yards - 8 Iron',
#        'Distance Analysis 170-180 yards - 9 Iron',
#        'Distance Analysis 170-180 yards - Wedges',
#        'Distance Analysis 160-170 yards - Fairway Wood',
#        'Distance Analysis 160-170 yards - 3 Iron',
#        'Distance Analysis 160-170 yards - 4 Iron',
#        'Distance Analysis 160-170 yards - 5 Iron',
#        'Distance Analysis 160-170 yards - 6 Iron',
#        'Distance Analysis 160-170 yards - 7 Iron',
#        'Distance Analysis 160-170 yards - 8 Iron',
#        'Distance Analysis 160-170 yards - 9 Iron',
#        'Distance Analysis 160-170 yards - Wedges',
#        'Distance Analysis 150-160 yards - 5 Iron',
#        'Distance Analysis 150-160 yards - 6 Iron',
#        'Distance Analysis 150-160 yards - 7 Iron',
#        'Distance Analysis 150-160 yards - 8 Iron',
#        'Distance Analysis 150-160 yards - 9 Iron',
#        'Distance Analysis 150-160 yards - Wedges',
#        'Distance Analysis 140-150 yards - 5 Iron',
#        'Distance Analysis 140-150 yards - 6 Iron',
#        'Distance Analysis 140-150 yards - 7 Iron',
#        'Distance Analysis 140-150 yards - 8 Iron',
#        'Distance Analysis 140-150 yards - 9 Iron',
#        'Distance Analysis 140-150 yards - Wedges',
#        'Distance Analysis 130-140 yards - 4 Iron',
#        'Distance Analysis 130-140 yards - 6 Iron',
#        'Distance Analysis 130-140 yards - 7 Iron',
#        'Distance Analysis 130-140 yards - 8 Iron',
#        'Distance Analysis 130-140 yards - 9 Iron',
#        'Distance Analysis 130-140 yards - Wedges',
#        'Distance Analysis 120-130 yards - Fairway Wood',
#        'Distance Analysis 120-130 yards - 6 Iron',
#        'Distance Analysis 120-130 yards - 8 Iron',
#        'Distance Analysis 120-130 yards - 9 Iron',
#        'Distance Analysis 120-130 yards - Wedges',
#        'Distance Analysis 110-120 yards - Fairway Wood',
#        'Distance Analysis 110-120 yards - 7 Iron',
#        'Distance Analysis 110-120 yards - 9 Iron',
#        'Distance Analysis 110-120 yards - Wedges',
#        'Distance Analysis 100-110 yards - Fairway Wood',
#        'Distance Analysis 100-110 yards - 9 Iron',
#        'Distance Analysis 100-110 yards - Wedges',
#        'Distance Analysis < 80 yards - Fairway Wood',
#        'Distance Analysis < 80 yards - 2 Iron',
#        'Distance Analysis < 80 yards - Wedges',
#        'Average Approach Shot Distance', "Putting from 5-15'",
#        "Putting from 15-25'", 'Approaches from inside 100 yards',
#        'GIR Percentage - < 100 yards', 'Approaches from > 100 yards',
#        'GIR Percentage - 100+ yards',
#        'Birdie or Better Percentage - Fairway',
#        'Birdie or Better Percentage - Left Rough',
#        'Birdie or Better Percentage - Right Rough',
#        'Birdie or Better Percentage - Rough',
#        'Percentage of Available Purse Won',
#        'Average Approach Distance - Birdie or Better',
#        'Average Approach Distance - Par',
#        'Average Approach Distance - Bogey or Worse',
#        'Percentage of Yardage covered by Tee Shots',
#        "Percentage of Yardage covered by Tee Shots - Par 4's",
#        "Percentage of Yardage covered by Tee Shots - Par 5's",
#        'Scoring Rating', 'Last 5 Events - Power',
#        'Last 5 Events - Accuracy', 'Last 5 Events - Short Game',
#        'Last 5 Events - Putting', 'Last 5 Events - Scoring',
#        'Last 15 Events - Power', 'Last 15 Events - Accuracy',
#        'Last 15 Events - Short Game', 'Last 15 Events - Putting',
#        'Last 15 Events - Scoring',
#        'Going for the Green - Birdie or Better',
#        'Approaches from 200-225 yards', 'Approaches from 225-250 yards',
#        'Approaches from 250-275 yards', 'Approaches from > 275 yards',
#        'Approaches from 50-75 yards (Rgh)',
#        'Approaches from 75-100 yards (Rgh)',
#        'Approaches from 100-125 yards (Rgh)',
#        'Approaches from 50-125 yards (Rgh)',
#        'Approaches from 125-150 yards (Rgh)',
#        'Approaches from 150-175 yards (Rgh)',
#        'Approaches from 175-200 yards (Rgh)',
#        'Approaches from > 200 yards (Rgh)',
#        'Approaches from inside 100 yards (Rgh)',
#        'Approaches from > 100 yards (Rgh)',
#        'Approaches from 200-225 yards (Rgh)',
#        'Approaches from 225-250 yards (Rgh)',
#        'Approaches from 250-275 yards (Rgh)',
#        'Approaches from > 275 yards (Rgh)',
#        'Approach 200-225 yards (RTP)', 'Approach 225-250 yards (RTP)',
#        'Approach 250-275 yards (RTP)', 'Approach > 275 yards (RTP)',
#        'Approaches 50-75 yards-Rgh (RTP)',
#        'Approaches 75-100 yards-Rgh (RTP)',
#        'Approaches 100-125 yards-Rgh (RTP)',
#        'Approaches 50-125 yards-Rgh (RTP)',
#        'Approaches 125-150 yards-Rgh (RTP)',
#        'Approaches 150-175 yards-Rgh (RTP)',
#        'Approaches 175-200 yards-Rgh (RTP)',
#        'Approaches > 200 yards-Rgh (RTP)',
#        'Approaches < 100 yards-Rgh (RTP)',
#        'Approaches > 100 yards-Rgh (RTP)',
#        'Approaches 200-225 yards-Rgh (RTP)',
#        'Approaches 225-250 yards-Rgh (RTP)',
#        'Approaches 250-275 yards-Rgh (RTP)',
#        'Approaches > 275 yards-Rgh (RTP)', 'FedExCup Season Points',
#        'FedExCup Playoffs Points', 'FedExCup Bonus Money',
#        'FedExCup Season Points for Non-Members', 'Club Head Speed',
#        'Ball Speed', 'Smash Factor', 'Launch Angle', 'Spin Rate',
#        'Distance to Apex', 'Apex Height', 'Hang Time', 'Carry Distance',
#        'Carry Efficiency', 'Total Distance Efficiency',
#        'Total Driving Efficiency', 'Bogey Avoidance',
#        'Birdie to Bogey Ratio', 'Reverse Bounce Back',
#        'Stroke Differential Field Average', 'Bogey Average',
#        'Distance from Edge of Fairway', 'Distance from Center of Fairway',
#        'Left Tendency', 'Right Tendency',
#        'Average Going for it Shot Distance (in Yards)',
#        "Putting from 3-5'", 'Total Putting', "Putting from - > 20'",
#        'Average Distance to Hole After Tee Shot',
#        'Average Distance after Going for it Shot',
#        'Driving Pct. 300-320 (All Drives)',
#        'Driving Pct. 320+ (All Drives)', 'GIR Pct. - Fairway Bunker',
#        'Rough Tendency', 'Greens or Fringe in Regulation',
#        'Good Drive Percentage', 'Bonus Putting',
#        'Average Distance of Birdie putts made',
#        'Average Distance of Eagle putts made',
#        'Money Leaders - Fall Series', 'Percentage of potential money won',
#        '% of Potential Pts won - FedExCup Regular Season',
#        '% of Potential Pts won - FedExCup Playoffs',
#        'FedExCup Points per Event Leaders', 'SG: Putting',
#        'SG: Off-the-Tee', 'SG: Approach-the-Green',
#        'SG: Around-the-Green',
#        'Non-WGC FedExCup Season Points for Non-Members',
#        'FedExCup Standings', 'Consecutive Birdies Streak',
#        'Consecutive Birdies/Eagles streak', 'SG: Tee-to-Green',
#        'SG: Total', 'Non-Member Off+WGC Earnings',
#        'Approach 100-125 yards (RTP Score)',
#        'Approach 75-100 yards (RTP Score)',
#        'Approach 50-75 yards (RTP Score)', "3-Putt Avoidance - Inside 5'",
#        "3-Putt Avoidance - 5-10'", "3-Putt Avoidance - 10-15'",
#        "GIR Putting Avg - 25-30'", "GIR Putting Avg - 30-35'",
#        "GIR Putting Avg - > 35'", 'Approaches from 100-125 yards',
#        'Approaches from 75-100 yards', 'Approaches from 50-75 yards',
#        'GIR Percentage - 100-125 yards', 'GIR Percentage - 75-100 yards',
#        'GIR Percentage - < 75 yards', 'Right Rough Tendency (RTP Score)',
#        'Left Rough Tendency (RTP Score)', 'Power Rating',
#        'Accuracy Rating', 'Short Game Rating', 'Putting Rating',
#        'Fairway Bunker Tendency',
#        'Distance Analysis 200-210 yards - Driver',
#        'Distance Analysis 190-200 yards - Driver',
#        'Distance Analysis 160-170 yards - Driver',
#        'Distance Analysis 150-160 yards - Driver',
#        'Distance Analysis < 80 yards - Driver',
#        'Distance Analysis 240-260 yards - Driver',
#        'Distance Analysis 150-160 yards - Fairway Wood',
#        'Distance Analysis 140-150 yards - Fairway Wood',
#        'Distance Analysis 120-130 yards - Driver',
#        'Distance Analysis 110-120 yards - Driver',
#        'Distance Analysis 100-110 yards - Driver', 'Official Money',
#        'Distance Analysis 150-160 yards - 4 Iron',
#        'Distance Analysis 140-150 yards - Driver',
#        'Distance Analysis 120-130 yards - 7 Iron',
#        'Distance Analysis 100-110 yards - 5 Iron',
#        '2019 PGA Championship Points'], dtype=object)

# %%
drive=golf[golf['Statistic']=='Driving Distance']

# %%
driver=drive[drive['Variable']=='Driving Distance - (AVG.)']

# %%
driver=driver.rename(columns={'Value':'Drive_average'})

# %%
fairways=golf[golf['Variable']=='Hit Fairway Percentage - (%)']

# %%
fairways[fairways['Player Name']=='Joe Durant']
# Out:
#        Player Name  Season               Statistic  \
# 48014   Joe Durant    2010  Hit Fairway Percentage
# 369726  Joe Durant    2011  Hit Fairway Percentage
#
#                             Variable  Value
# 48014   Hit Fairway Percentage - (%)  76.05
# 369726  Hit Fairway Percentage - (%)  76.44

# %%
scramble=golf[golf['Statistic']=='Scrambling']

# %%
scrambling=scramble[scramble['Variable']=='Scrambling - (%)']

# %%
scrambling[scrambling['Player Name']=='Tiger Woods']
# Out:
#          Player Name  Season   Statistic          Variable  Value
# 642151   Tiger Woods    2012  Scrambling  Scrambling - (%)  63.17
# 953077   Tiger Woods    2013  Scrambling  Scrambling - (%)  60.00
# 2447319  Tiger Woods    2018  Scrambling  Scrambling - (%)  64.16

# %%
putt=golf[golf['Statistic']=='Overall Putting Average']

# %%
putting=putt[putt['Variable']=='Overall Putting Average - (AVG)']

# %%
putting=putting.rename(columns={'Variable':'Putting Average','Value':'Putts Average per hole'})

# %%
score=golf[golf['Statistic']=='Scoring Average']

# %%
scoring=score[score['Variable']=='Scoring Average - (AVG)']

# %%
scoring=scoring.rename(columns={'Variable':'Score AVG','Value':'Average Score per Round'})

# %%
gir=golf[golf['Statistic']=='Greens in Regulation Percentage']

# %%
greens=gir[gir['Variable']=='Greens in Regulation Percentage - (%)']

# %%
greens=greens.rename(columns={'Variable':'Greens in Regulation Percentage','Value':'Percentage of Greens hit in Regulation'})

# %%
scramfairway=pd.merge(fairways,scrambling,on=['Player Name','Season'],suffixes=('_fairways_%','_scrambling_%'),how='left')

# %%
fairscramputt=pd.merge(scramfairway,putting,on=['Player Name','Season'],how='left')

# %%
fairscramputtscore=pd.merge(fairscramputt,scoring,on=['Player Name','Season'],how='left')

# %%
total=pd.merge(fairscramputtscore,greens,on=['Player Name','Season'],how='left')

# %%
totals=pd.merge(total,driver,on=['Player Name','Season'],how='left')

# %%
col3=[  'Statistic_fairways_%',
       'Variable_fairways_%',
       'Statistic_scrambling_%', 'Variable_scrambling_%',
        'Statistic_x', 'Putting Average','Statistic_y', 
        'Statistic_x','Greens in Regulation Percentage', 'Statistic_y',
       'Variable','Score AVG']

# %%
totals.head()
# Out:
#     Player Name  Season    Statistic_fairways_%           Variable_fairways_%  \
# 0   Omar Uresti    2010  Hit Fairway Percentage  Hit Fairway Percentage - (%)
# 1    Joe Durant    2010  Hit Fairway Percentage  Hit Fairway Percentage - (%)
# 2  Craig Bowden    2010  Hit Fairway Percentage  Hit Fairway Percentage - (%)
# 3     Brian Gay    2010  Hit Fairway Percentage  Hit Fairway Percentage - (%)
# 4     Tim Clark    2010  Hit Fairway Percentage  Hit Fairway Percentage - (%)
#
#   Value_fairways_% Statistic_scrambling_% Variable_scrambling_%  \
# 0            76.36             Scrambling      Scrambling - (%)
# 1            76.05             Scrambling      Scrambling - (%)
# 2            73.98             Scrambling      Scrambling - (%)
# 3            73.86             Scrambling      Scrambling - (%)
# 4            73.12             Scrambling      Scrambling - (%)
#
#   Value_scrambling_%              Statistic_x  \
# 0              61.44  Overall Putting Average
# 1              59.09  Overall Putting Average
# 2              58.31  Overall Putting Average
# 3              66.51  Overall Putting Average
# 4              62.67  Overall Putting Average
#
#                    Putting Average Putts Average per hole      Statistic_y  \
# 0  Overall Putting Average - (AVG)                  1.520  Scoring Average
# 1  Overall Putting Average - (AVG)                  1.512  Scoring Average
# 2  Overall Putting Average - (AVG)                  1.494  Scoring Average
# 3  Overall Putting Average - (AVG)                  1.557  Scoring Average
# 4  Overall Putting Average - (AVG)                  1.604  Scoring Average
#
#                  Score AVG Average Score per Round  \
# 0  Scoring Average - (AVG)                  71.579
# 1  Scoring Average - (AVG)                  70.365
# 2  Scoring Average - (AVG)                  72.229
# 3  Scoring Average - (AVG)                  70.756
# 4  Scoring Average - (AVG)                  70.246
#
#                        Statistic_x        Greens in Regulation Percentage  \
# 0  Greens in Regulation Percentage  Greens in Regulation Percentage - (%)
# 1  Greens in Regulation Percentage  Greens in Regulation Percentage - (%)
# 2  Greens in Regulation Percentage  Greens in Regulation Percentage - (%)
# 3  Greens in Regulation Percentage  Greens in Regulation Percentage - (%)
# 4  Greens in Regulation Percentage  Greens in Regulation Percentage - (%)
#
#   Percentage of Greens hit in Regulation       Statistic_y  \
# 0                                  68.22  Driving Distance
# 1                                  71.95  Driving Distance
# 2                                  62.64  Driving Distance
# 3                                  63.44  Driving Distance
# 4                                  66.73  Driving Distance
#
#                     Variable Drive_average
# 0  Driving Distance - (AVG.)         272.0
# 1  Driving Distance - (AVG.)         285.6
# 2  Driving Distance - (AVG.)         270.0
# 3  Driving Distance - (AVG.)         266.4
# 4  Driving Distance - (AVG.)         272.2

# %%
totals=totals.drop(col3,axis=1)

# %%
totals.head()
# Out:
#     Player Name  Season Value_fairways_% Value_scrambling_%  \
# 0   Omar Uresti    2010            76.36              61.44
# 1    Joe Durant    2010            76.05              59.09
# 2  Craig Bowden    2010            73.98              58.31
# 3     Brian Gay    2010            73.86              66.51
# 4     Tim Clark    2010            73.12              62.67
#
#   Putts Average per hole Average Score per Round  \
# 0                  1.520                  71.579
# 1                  1.512                  70.365
# 2                  1.494                  72.229
# 3                  1.557                  70.756
# 4                  1.604                  70.246
#
#   Percentage of Greens hit in Regulation Drive_average
# 0                                  68.22         272.0
# 1                                  71.95         285.6
# 2                                  62.64         270.0
# 3                                  63.44         266.4
# 4                                  66.73         272.2

# %%
total=totals.rename(columns={'Season_fairways_%':'Seasons','Value_fairways_%':'fairways_hit_%','Value_scrambling_%':'Scrambling_%','Percentage of Greens hit in Regulation':'Percent_of_greens_in_reg'})

# %%
total['fairways_hit_%'] = total['fairways_hit_%'].astype(float)

# %%
total['Scrambling_%'] = total['Scrambling_%'].astype(float)

# %%
total['Putts Average per hole'] = total['Putts Average per hole'].astype(float)

# %%
total['Average Score per Round'] = total['Average Score per Round'].astype(float)

# %%
total['Percent_of_greens_in_reg'] = total['Percent_of_greens_in_reg'].astype(float)

# %%
total['Drive_average'] = total['Drive_average'].astype(float)

# %%
total.head(30)
# Out:
#         Player Name  Season  fairways_hit_%  Scrambling_%  \
# 0       Omar Uresti    2010           76.36         61.44
# 1        Joe Durant    2010           76.05         59.09
# 2      Craig Bowden    2010           73.98         58.31
# 3         Brian Gay    2010           73.86         66.51
# 4         Tim Clark    2010           73.12         62.67
# 5         Jim Furyk    2010           72.03         63.47
# 6      Heath Slocum    2010           71.64         62.87
# 7        David Toms    2010           71.52         61.29
# 8        Alex Cejka    2010           71.32         56.42
# 9   Richard Johnson    2010           70.55         59.35
# 10   John Mallinger    2010           70.54         58.67
# 11   Garrett Willis    2010           70.53         55.32
# 12     Zach Johnson    2010           70.46         57.66
# 13     Jeff Quinney    2010           70.38         59.70
# 14     Skip Kendall    2010           70.35         57.57
# 15       Ben Curtis    2010           70.31         59.69
# 16    Billy Mayfair    2010           70.10         55.50
# 17        Ben Crane    2010           70.09         59.06
# 18      Jerry Kelly    2010           70.02         57.91
# 19      Paul Goydos    2010           69.80         55.02
# 20    Chris DiMarco    2010           69.65         61.87
# 21    Chad Campbell    2010           69.40         59.46
# 22      Chris Riley    2010           69.30         64.47
# 23   Justin Leonard    2010           69.13         57.32
# 24   Jay Williamson    2010           69.11         59.74
# 25       Tom Gillis    2010           69.04         60.27
# 26   Scott Verplank    2010           69.03         59.37
# 27    Rocco Mediate    2010           68.93         56.96
# 28     Cliff Kresge    2010           68.92         59.06
# 29      Mark Wilson    2010           68.91         62.16
#
#     Putts Average per hole  Average Score per Round  Percent_of_greens_in_reg  \
# 0                    1.520                   71.579                     68.22
# 1                    1.512                   70.365                     71.95
# 2                    1.494                   72.229                     62.64
# 3                    1.557                   70.756                     63.44
# 4                    1.604                   70.246                     66.73
# 5                    1.597                   69.828                     67.12
# 6                    1.578                   70.673                     69.59
# 7                    1.605                   70.337                     67.58
# 8                    1.609                   71.219                     66.60
# 9                    1.498                   71.156                     68.50
# 10                   1.588                   71.270                     67.11
# 11                   1.567                   71.159                     69.87
# 12                   1.596                   70.527                     66.54
# 13                   1.522                   70.851                     65.45
# 14                   1.390                   71.640                     62.56
# 15                   1.645                   70.871                     68.02
# 16                   1.521                   71.426                     69.68
# 17                   1.615                   70.234                     68.22
# 18                   1.580                   70.954                     67.49
# 19                   1.615                   71.532                     65.95
# 20                   1.546                   70.983                     67.39
# 21                   1.641                   70.629                     69.06
# 22                   1.479                   70.345                     67.33
# 23                   1.612                   70.419                     65.09
# 24                   1.477                   71.290                     68.95
# 25                   1.597                   70.514                     65.98
# 26                   1.597                   70.838                     63.85
# 27                   1.635                   71.341                     69.32
# 28                   1.521                   71.417                     66.67
# 29                   1.575                   71.098                     70.28
#
#     Drive_average
# 0           272.0
# 1           285.6
# 2           270.0
# 3           266.4
# 4           272.2
# 5           276.0
# 6           278.9
# 7           281.3
# 8           277.4
# 9           277.3
# 10          280.4
# 11          280.2
# 12          279.7
# 13          273.3
# 14          279.5
# 15          275.5
# 16          284.0
# 17          282.3
# 18          279.0
# 19          273.6
# 20          279.0
# 21          285.1
# 22          278.3
# 23          277.8
# 24          285.1
# 25          288.7
# 26          278.6
# 27          278.1
# 28          283.2
# 29          280.6
